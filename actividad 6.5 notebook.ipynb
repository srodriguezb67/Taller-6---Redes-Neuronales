# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 11-12: Introducción a redes neuronales
#
# - Redes densas
# - Redes para regresión
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy y pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('auto-mpg.data',
                 names=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin'],
                 sep=' ',
                 na_values='?',
                 comment='\t',
                 skipinitialspace=True
                 )

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df=df.drop(["Origin"], axis=1)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 7 columns]

# %% [markdown]
# - MPG: miles per gallon
# - Cylinders: # de cilindros
# - Displacement: volumen desplazado por los pistones
# - Horsepower: caballos de potencia
# - Weight: peso
# - Acceleration: aceleración
# - Model Year: año/modelo
# - Origin: 1:USA, 2:Europa, 3:Japón

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (398, 7)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %% [markdown]
# Separamos los datos en entrenamiento y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 125  20.0          6         198.0        95.0  3102.0          16.5
# 142  26.0          4          79.0        67.0  1963.0          15.5
# 278  31.5          4          89.0        71.0  1990.0          14.9
# 254  20.2          6         200.0        85.0  2965.0          15.8
# 328  30.0          4         146.0        67.0  3250.0          21.8
#
#      Model Year
# 125          74
# 142          74
# 278          78
# 254          78
# 328          80

# %%
test = df.drop(train.index)
test.head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0   18.0          8         307.0       130.0  3504.0          12.0
# 2   18.0          8         318.0       150.0  3436.0          11.0
# 4   17.0          8         302.0       140.0  3449.0          10.5
# 8   14.0          8         455.0       225.0  4425.0          10.0
# 13  14.0          8         455.0       225.0  3086.0          10.0
#
#     Model Year
# 0           70
# 2           70
# 4           70
# 8           70
# 13          70

# %%
print(train.shape)
print(test.shape)
# Out:
# (314, 7)
# (78, 7)

# %% [markdown]
# Realicemos una exploración descriptiva de los datos, calculando inicialmente estadísticas de cada variable continua

# %%
train.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.579299    5.455414    192.562102  103.767516  2959.312102
# std      7.877216    1.691811    103.701434   38.123560   856.880939
# min      9.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.125000    4.000000     98.000000   75.000000  2193.000000
# 50%     23.000000    4.000000    146.000000   94.500000  2764.500000
# 75%     29.375000    8.000000    260.000000  120.000000  3612.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year
# count    314.000000  314.000000
# mean      15.518471   75.964968
# std        2.705097    3.672110
# min        8.000000   70.000000
# 25%       13.900000   73.000000
# 50%       15.500000   76.000000
# 75%       17.000000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Exploremos relaciones bivariadas con pairplot de seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(train)

# %% [markdown]
# Calculemos la matriz de correlacion

# %%
train.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777230     -0.807032   -0.775493 -0.832793
# Cylinders    -0.777230   1.000000      0.950858    0.849237  0.901259
# Displacement -0.807032   0.950858      1.000000    0.893640  0.941913
# Horsepower   -0.775493   0.849237      0.893640    1.000000  0.875157
# Weight       -0.832793   0.901259      0.941913    0.875157  1.000000
# Acceleration  0.389422  -0.488703     -0.523473   -0.672989 -0.402870
# Model Year    0.596816  -0.330668     -0.364236   -0.414065 -0.318231
#
#               Acceleration  Model Year
# MPG               0.389422    0.596816
# Cylinders        -0.488703   -0.330668
# Displacement     -0.523473   -0.364236
# Horsepower       -0.672989   -0.414065
# Weight           -0.402870   -0.318231
# Acceleration      1.000000    0.258013
# Model Year        0.258013    1.000000

# %%
sns.heatmap(train.corr())
# Out:
# <Axes: >

# %% [markdown]
# Seleccionamos ahora las características y las etiquetas (MPG)

# %%
train_X = train.copy()
test_X = test.copy()

# %%
train_y = train_X.pop('MPG')
test_y = test_X.pop('MPG')

# %%
train_X.head()
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74
# 142          4          79.0        67.0  1963.0          15.5          74
# 278          4          89.0        71.0  1990.0          14.9          78
# 254          6         200.0        85.0  2965.0          15.8          78
# 328          4         146.0        67.0  3250.0          21.8          80

# %%
train_y.head()
# Out:
# 125    20.0
# 142    26.0
# 278    31.5
# 254    20.2
# 328    30.0
# Name: MPG, dtype: float64

# %%
train_X.dtypes
# Out:
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model Year        int64
# dtype: object

# %% [markdown]
# Construyamos los modelos usando tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Capa de normalización

# %%
tf.keras.layers.Normalization
# Out:
# keras.src.layers.preprocessing.normalization.Normalization

# %%
norm = tf.keras.layers.Normalization()

# %%
norm.adapt(np.array(train_X))

# %%
norm.mean.numpy()
# Out:
# array([[   5.455414,  192.5621  ,  103.76752 , 2959.312   ,   15.518472,
#           75.964966]], dtype=float32)

# %%
norm.variance.numpy()
# Out:
# array([[2.8531077e+00, 1.0719739e+04, 1.4487772e+03, 7.3190656e+05,
#         7.2942448e+00, 1.3441448e+01]], dtype=float32)

# %%
np.sqrt(norm.variance.numpy())
# Out:
# array([[  1.6891145, 103.53617  ,  38.062805 , 855.5154   ,   2.7007859,
#           3.666258 ]], dtype=float32)

# %%
train_X[:1]
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74

# %%
norm(train_X[:1]).numpy()
# Out:
# array([[ 0.32240927,  0.05252171, -0.23034343,  0.166786  ,  0.36342323,
#         -0.5359595 ]], dtype=float32)

# %% [markdown]
# ## Modelo con múltiples variables de entrada

# %%
linear_model = tf.keras.Sequential([
    norm,
    tf.keras.layers.Dense(units=1)
])

# %%
linear_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (314, 6)               │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_X,
    train_y,
    epochs=100,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.9689 - val_loss: 21.6980
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.9822 - val_loss: 21.0227
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.8874 - val_loss: 20.3315
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.9842 - val_loss: 19.6145
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.3576 - val_loss: 18.9800
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.3943 - val_loss: 18.2743
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.0678 - val_loss: 17.6581
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.1119 - val_loss: 16.9456
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.0954 - val_loss: 16.2315
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.2112 - val_loss: 15.5941
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.4434 - val_loss: 14.9070
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.3256 - val_loss: 14.2141
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.8905 - val_loss: 13.5256
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.7748 - val_loss: 12.8392
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.7461 - val_loss: 12.2333
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.1266 - val_loss: 11.5357
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.4884 - val_loss: 10.7976
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7518 - val_loss: 10.0694
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6138 - val_loss: 9.3424
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5384 - val_loss: 8.4309
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5310 - val_loss: 7.5836
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7671 - val_loss: 6.7648
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4051 - val_loss: 6.0594
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6991 - val_loss: 5.1950
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8282 - val_loss: 4.4254
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4058 - val_loss: 3.6161
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1238 - val_loss: 3.0468
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3404 - val_loss: 2.7573
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0623 - val_loss: 2.6943
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8698 - val_loss: 2.3666
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0425 - val_loss: 2.3164
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8462 - val_loss: 2.4021
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7639 - val_loss: 2.2829
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5597 - val_loss: 2.2520
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6711 - val_loss: 2.3431
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5448 - val_loss: 2.3093
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4861 - val_loss: 2.2314
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5566 - val_loss: 2.2263
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0532 - val_loss: 2.2682
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8324 - val_loss: 2.2046
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5842 - val_loss: 2.2366
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7517 - val_loss: 2.2175
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6357 - val_loss: 2.2065
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5343 - val_loss: 2.2362
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6576 - val_loss: 2.3025
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5166 - val_loss: 2.2135
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8463 - val_loss: 2.2680
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6507 - val_loss: 2.3557
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4121 - val_loss: 2.1869
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6346 - val_loss: 2.2982
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5758 - val_loss: 2.2834
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6603 - val_loss: 2.2494
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6528 - val_loss: 2.2324
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7167 - val_loss: 2.2919
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6996 - val_loss: 2.2800
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4829 - val_loss: 2.2251
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5657 - val_loss: 2.3028
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5881 - val_loss: 2.2152
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5821 - val_loss: 2.3035
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6141 - val_loss: 2.2601
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6962 - val_loss: 2.2876
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4959 - val_loss: 2.2633
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7277 - val_loss: 2.2739
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5622 - val_loss: 2.2629
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7431 - val_loss: 2.2941
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6027 - val_loss: 2.2789
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6730 - val_loss: 2.2127
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6120 - val_loss: 2.2873
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5760 - val_loss: 2.3075
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6449 - val_loss: 2.2373
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7641 - val_loss: 2.2760
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7482 - val_loss: 2.2660
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6481 - val_loss: 2.3029
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6812 - val_loss: 2.2457
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7495 - val_loss: 2.2428
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6597 - val_loss: 2.3057
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4865 - val_loss: 2.2975
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5329 - val_loss: 2.2601
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7690 - val_loss: 2.2534
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5992 - val_loss: 2.2594
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6067 - val_loss: 2.2524
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5735 - val_loss: 2.3524
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8139 - val_loss: 2.2219
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6128 - val_loss: 2.3014
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4793 - val_loss: 2.3401
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5814 - val_loss: 2.2279
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6815 - val_loss: 2.2752
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6832 - val_loss: 2.2795
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6100 - val_loss: 2.2773
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5856 - val_loss: 2.2341
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5673 - val_loss: 2.2915
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4839 - val_loss: 2.2656
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4962 - val_loss: 2.1974
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4635 - val_loss: 2.3882
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6010 - val_loss: 2.3007
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7209 - val_loss: 2.1761
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5918 - val_loss: 2.3357
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8164 - val_loss: 2.3009
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6735 - val_loss: 2.2666
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5796 - val_loss: 2.2775
# CPU times: total: 1.03 s
# Wall time: 4.68 s

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res = {}
test_res['linear_model'] = linear_model.evaluate(
    test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'linear_model': 2.7586874961853027}

# %%
dnn_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# variacion 1
variacion1_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='sigmoid'),
      tf.keras.layers.Dense(64, activation='sigmoid'),
      tf.keras.layers.Dense(1)
  ])


# variacion 2
variacion2_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='tanh'),
      tf.keras.layers.Dense(64, activation='tanh'),
      tf.keras.layers.Dense(1)
  ])


# variacion 3
variacion3_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='softplus'),
      tf.keras.layers.Dense(64, activation='softplus'),
      tf.keras.layers.Dense(1)
  ])

# %%
dnn_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# variacion 1
variacion1_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 2
variacion2_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 3
variacion3_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
dnn_model.summary()

# variacion 1
variacion1_model.summary()


# variacion 2
variacion2_model.summary()


# variacion 3
variacion3_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
# %%time
history_original = dnn_model.fit(
  train_X,
  train_y,
  validation_split=0.2,
  epochs=100)

  # variacion 1
history_variacion1 = variacion1_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)


# variacion 2
history_variacion2 = variacion2_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)

# variacion 3
history_variacion3 = variacion3_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 23.7464 - val_loss: 21.7470
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.1731 - val_loss: 21.2014
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.9487 - val_loss: 20.5115
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.7659 - val_loss: 19.5961
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.9983 - val_loss: 18.3527
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.8857 - val_loss: 16.6748
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.1842 - val_loss: 14.6905
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.1839 - val_loss: 12.7133
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.4504 - val_loss: 10.7925
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.4365 - val_loss: 8.5002
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9681 - val_loss: 6.2827
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3911 - val_loss: 5.3195
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3469 - val_loss: 5.2485
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2441 - val_loss: 4.7224
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8387 - val_loss: 4.3613
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7539 - val_loss: 4.1139
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6384 - val_loss: 3.8603
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2167 - val_loss: 3.6564
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1528 - val_loss: 3.4535
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8494 - val_loss: 3.3108
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6960 - val_loss: 3.1772
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5145 - val_loss: 3.0531
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3716 - val_loss: 2.9321
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4817 - val_loss: 2.8235
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0346 - val_loss: 2.7459
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0239 - val_loss: 2.6339
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7739 - val_loss: 2.6040
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9216 - val_loss: 2.5232
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8025 - val_loss: 2.4645
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6626 - val_loss: 2.4267
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6614 - val_loss: 2.3528
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6068 - val_loss: 2.3177
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7169 - val_loss: 2.3436
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5697 - val_loss: 2.2010
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4635 - val_loss: 2.1778
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5564 - val_loss: 2.2334
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4289 - val_loss: 2.2102
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2695 - val_loss: 2.1198
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4258 - val_loss: 2.1312
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1589 - val_loss: 2.1088
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4099 - val_loss: 2.1032
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3046 - val_loss: 2.1369
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2999 - val_loss: 2.0406
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1950 - val_loss: 2.0842
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1649 - val_loss: 2.0826
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2875 - val_loss: 2.0324
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2384 - val_loss: 2.0365
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2786 - val_loss: 2.0363
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1293 - val_loss: 2.0212
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2362 - val_loss: 1.9828
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2665 - val_loss: 1.9657
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2051 - val_loss: 2.0647
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1086 - val_loss: 1.9865
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0564 - val_loss: 1.9415
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1416 - val_loss: 2.0043
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2005 - val_loss: 1.9207
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0356 - val_loss: 1.9885
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0890 - val_loss: 1.9629
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0410 - val_loss: 1.9080
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0418 - val_loss: 1.9407
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0731 - val_loss: 1.9521
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0023 - val_loss: 1.9167
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2100 - val_loss: 1.9319
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1298 - val_loss: 1.8951
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8919 - val_loss: 1.9220
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0994 - val_loss: 1.8897
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0063 - val_loss: 1.9159
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9525 - val_loss: 1.8910
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8977 - val_loss: 1.8947
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0050 - val_loss: 1.8812
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1195 - val_loss: 1.8854
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0196 - val_loss: 1.8773
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9961 - val_loss: 1.8464
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9416 - val_loss: 1.8881
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0702 - val_loss: 1.8895
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9837 - val_loss: 1.8505
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0886 - val_loss: 1.9030
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8689 - val_loss: 1.8243
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0780 - val_loss: 1.8249
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9808 - val_loss: 1.8629
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0004 - val_loss: 1.8621
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9606 - val_loss: 1.8454
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0612 - val_loss: 1.8342
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0598 - val_loss: 1.8324
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9118 - val_loss: 1.8423
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0994 - val_loss: 1.8368
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8189 - val_loss: 1.8491
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9063 - val_loss: 1.8706
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9900 - val_loss: 1.7919
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8057 - val_loss: 1.9022
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1033 - val_loss: 1.8507
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8111 - val_loss: 1.8642
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8556 - val_loss: 1.8379
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9521 - val_loss: 1.8614
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8133 - val_loss: 1.8292
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7780 - val_loss: 1.8796
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8388 - val_loss: 1.9035
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9088 - val_loss: 1.8509
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7204 - val_loss: 1.8799
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7653 - val_loss: 1.8026
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 24.0997 - val_loss: 21.8894
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.2678 - val_loss: 21.1214
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.3702 - val_loss: 20.3885
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.5451 - val_loss: 19.6974
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.2263 - val_loss: 19.0499
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.3648 - val_loss: 18.4447
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.9836 - val_loss: 17.8766
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.1260 - val_loss: 17.3398
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.8204 - val_loss: 16.8289
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.8399 - val_loss: 16.3390
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2431 - val_loss: 15.8679
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.9152 - val_loss: 15.4119
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.1020 - val_loss: 14.9705
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.6611 - val_loss: 14.5414
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.4203 - val_loss: 14.1227
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.3394 - val_loss: 13.7126
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.8740 - val_loss: 13.3101
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.7674 - val_loss: 12.9186
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.0903 - val_loss: 12.5245
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.1949 - val_loss: 12.1296
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.9041 - val_loss: 11.7366
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.0621 - val_loss: 11.3504
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.3004 - val_loss: 10.9809
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.2257 - val_loss: 10.6138
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.8176 - val_loss: 10.2702
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.0466 - val_loss: 9.9323
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.2950 - val_loss: 9.6043
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.6254 - val_loss: 9.3036
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.0107 - val_loss: 9.0064
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7787 - val_loss: 8.7367
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9407 - val_loss: 8.4962
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5472 - val_loss: 8.2614
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7945 - val_loss: 8.0561
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7193 - val_loss: 7.8750
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7877 - val_loss: 7.7025
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7030 - val_loss: 7.5248
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3745 - val_loss: 7.3487
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4699 - val_loss: 7.1579
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6545 - val_loss: 6.9523
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7580 - val_loss: 6.7460
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6289 - val_loss: 6.5382
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3428 - val_loss: 6.3296
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3558 - val_loss: 6.1374
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4611 - val_loss: 5.9613
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5632 - val_loss: 5.7966
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4005 - val_loss: 5.6455
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2207 - val_loss: 5.5037
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3555 - val_loss: 5.3766
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1433 - val_loss: 5.2535
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7755 - val_loss: 5.1441
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9015 - val_loss: 5.0413
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8369 - val_loss: 4.9468
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6646 - val_loss: 4.8675
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4883 - val_loss: 4.7910
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3379 - val_loss: 4.7254
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5851 - val_loss: 4.6440
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1693 - val_loss: 4.5663
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3998 - val_loss: 4.4877
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2495 - val_loss: 4.4179
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3225 - val_loss: 4.3498
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9957 - val_loss: 4.2939
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8065 - val_loss: 4.2354
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0177 - val_loss: 4.1849
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0245 - val_loss: 4.1334
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0937 - val_loss: 4.0773
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4067 - val_loss: 4.0296
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3492 - val_loss: 3.9769
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6671 - val_loss: 3.9286
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6439 - val_loss: 3.8728
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6011 - val_loss: 3.8100
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3558 - val_loss: 3.7510
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7213 - val_loss: 3.7000
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1638 - val_loss: 3.6435
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3726 - val_loss: 3.5869
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9097 - val_loss: 3.5452
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1287 - val_loss: 3.4912
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1485 - val_loss: 3.4422
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4825 - val_loss: 3.3982
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9780 - val_loss: 3.3505
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9204 - val_loss: 3.3176
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6306 - val_loss: 3.2797
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1061 - val_loss: 3.2398
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0655 - val_loss: 3.2090
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9746 - val_loss: 3.1743
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9898 - val_loss: 3.1409
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8099 - val_loss: 3.1133
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8755 - val_loss: 3.0894
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4891 - val_loss: 3.0703
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9730 - val_loss: 3.0461
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1820 - val_loss: 3.0129
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5769 - val_loss: 2.9895
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7765 - val_loss: 2.9656
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4998 - val_loss: 2.9547
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4823 - val_loss: 2.9451
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0513 - val_loss: 2.9220
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3500 - val_loss: 2.8873
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4832 - val_loss: 2.8937
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3206 - val_loss: 2.8851
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4279 - val_loss: 2.8666
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0864 - val_loss: 2.8553
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 23.3081 - val_loss: 22.3453
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.1996 - val_loss: 22.2317
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.1998 - val_loss: 22.1006
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0750 - val_loss: 21.9176
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.9308 - val_loss: 21.6692
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.6370 - val_loss: 21.3267
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.8255 - val_loss: 20.8723
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.2021 - val_loss: 20.2590
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.5701 - val_loss: 19.4180
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.5653 - val_loss: 18.2861
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.3330 - val_loss: 16.8070
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.8466 - val_loss: 15.0014
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6074 - val_loss: 13.0718
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.7188 - val_loss: 11.0040
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.7215 - val_loss: 9.1163
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3632 - val_loss: 7.6021
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3901 - val_loss: 6.4335
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3447 - val_loss: 5.5977
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3276 - val_loss: 5.0258
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7005 - val_loss: 4.6711
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2784 - val_loss: 4.4040
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3347 - val_loss: 4.2170
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1197 - val_loss: 4.1075
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7122 - val_loss: 4.0312
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6708 - val_loss: 4.0465
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4673 - val_loss: 3.9262
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1741 - val_loss: 3.8492
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4992 - val_loss: 3.7252
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2629 - val_loss: 3.6789
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2027 - val_loss: 3.5987
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9601 - val_loss: 3.5862
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9845 - val_loss: 3.5209
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9858 - val_loss: 3.5358
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7610 - val_loss: 3.4866
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6392 - val_loss: 3.5187
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0693 - val_loss: 3.3817
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7550 - val_loss: 3.4640
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4209 - val_loss: 3.3145
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7394 - val_loss: 3.4217
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5859 - val_loss: 3.2467
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6234 - val_loss: 3.2329
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5261 - val_loss: 3.2057
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2605 - val_loss: 3.1495
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4262 - val_loss: 3.1897
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6521 - val_loss: 3.0876
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5894 - val_loss: 3.0527
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5534 - val_loss: 3.1563
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3022 - val_loss: 3.0373
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3584 - val_loss: 2.9991
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4611 - val_loss: 2.9437
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1727 - val_loss: 2.9908
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0821 - val_loss: 2.8958
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0609 - val_loss: 2.9732
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1038 - val_loss: 2.9022
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2617 - val_loss: 2.8550
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0351 - val_loss: 2.8408
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4033 - val_loss: 2.8153
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3646 - val_loss: 2.7812
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0614 - val_loss: 2.7237
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8320 - val_loss: 2.7560
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2202 - val_loss: 2.7198
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0134 - val_loss: 2.6772
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0008 - val_loss: 2.7336
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9986 - val_loss: 2.7028
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1347 - val_loss: 2.6541
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8832 - val_loss: 2.5878
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9782 - val_loss: 2.5653
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8147 - val_loss: 2.5348
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9416 - val_loss: 2.4846
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9779 - val_loss: 2.4819
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8631 - val_loss: 2.4364
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6420 - val_loss: 2.4214
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6058 - val_loss: 2.3952
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5152 - val_loss: 2.3787
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7413 - val_loss: 2.3319
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6183 - val_loss: 2.3233
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7195 - val_loss: 2.2752
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7109 - val_loss: 2.2455
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6722 - val_loss: 2.2109
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5581 - val_loss: 2.2530
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7357 - val_loss: 2.2279
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6480 - val_loss: 2.1939
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3158 - val_loss: 2.1825
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6249 - val_loss: 2.1755
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6592 - val_loss: 2.1229
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7720 - val_loss: 2.0795
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3900 - val_loss: 2.0867
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4607 - val_loss: 2.0475
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6548 - val_loss: 2.0559
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4031 - val_loss: 2.0739
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2889 - val_loss: 2.0397
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3104 - val_loss: 1.9972
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3828 - val_loss: 1.9919
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3674 - val_loss: 1.9605
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4126 - val_loss: 1.9477
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4110 - val_loss: 1.9417
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4742 - val_loss: 1.9361
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3753 - val_loss: 1.9113
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2754 - val_loss: 1.9062
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4132 - val_loss: 1.8941
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 20.8174 - val_loss: 17.8397
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.3616 - val_loss: 14.8800
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.2202 - val_loss: 11.8376
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5513 - val_loss: 9.1926
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5697 - val_loss: 7.0995
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3967 - val_loss: 5.7174
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3138 - val_loss: 4.9616
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8236 - val_loss: 4.3542
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8795 - val_loss: 3.4906
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2780 - val_loss: 2.7169
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8836 - val_loss: 2.3302
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6289 - val_loss: 2.1607
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6505 - val_loss: 2.1024
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4126 - val_loss: 2.0909
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3600 - val_loss: 1.9479
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4418 - val_loss: 1.9280
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3208 - val_loss: 1.9009
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4829 - val_loss: 1.8507
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4409 - val_loss: 1.8211
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2312 - val_loss: 1.8132
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1289 - val_loss: 1.7588
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2637 - val_loss: 1.7526
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2273 - val_loss: 1.7352
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0984 - val_loss: 1.7342
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2858 - val_loss: 1.7015
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9768 - val_loss: 1.7345
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2421 - val_loss: 1.6796
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1403 - val_loss: 1.6970
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2172 - val_loss: 1.6890
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9906 - val_loss: 1.6620
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0054 - val_loss: 1.7102
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2632 - val_loss: 1.6334
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0657 - val_loss: 1.6732
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0380 - val_loss: 1.6436
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9391 - val_loss: 1.6235
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1350 - val_loss: 1.6258
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2097 - val_loss: 1.6125
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9464 - val_loss: 1.6050
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9858 - val_loss: 1.6191
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1529 - val_loss: 1.6296
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9646 - val_loss: 1.5965
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1168 - val_loss: 1.6020
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2104 - val_loss: 1.6453
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1348 - val_loss: 1.5702
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9608 - val_loss: 1.6564
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2601 - val_loss: 1.5672
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1098 - val_loss: 1.5926
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1016 - val_loss: 1.5867
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0559 - val_loss: 1.5935
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0409 - val_loss: 1.5832
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8940 - val_loss: 1.5737
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0170 - val_loss: 1.5567
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0549 - val_loss: 1.5746
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1511 - val_loss: 1.5428
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1005 - val_loss: 1.5358
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0380 - val_loss: 1.5543
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0482 - val_loss: 1.5444
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0148 - val_loss: 1.5548
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0287 - val_loss: 1.5449
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0369 - val_loss: 1.5384
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0944 - val_loss: 1.5223
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9434 - val_loss: 1.5843
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0587 - val_loss: 1.5112
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0433 - val_loss: 1.5448
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1788 - val_loss: 1.5319
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0734 - val_loss: 1.5057
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0576 - val_loss: 1.5046
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0626 - val_loss: 1.5273
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0745 - val_loss: 1.5167
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0574 - val_loss: 1.5152
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1287 - val_loss: 1.5193
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9644 - val_loss: 1.4894
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9799 - val_loss: 1.5088
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0222 - val_loss: 1.4926
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0355 - val_loss: 1.5061
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9294 - val_loss: 1.4971
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9912 - val_loss: 1.4819
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8524 - val_loss: 1.5330
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2486 - val_loss: 1.4714
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1115 - val_loss: 1.6080
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0445 - val_loss: 1.4757
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0224 - val_loss: 1.4785
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0760 - val_loss: 1.5071
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0211 - val_loss: 1.4915
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0332 - val_loss: 1.5032
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0779 - val_loss: 1.4935
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0008 - val_loss: 1.4748
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1625 - val_loss: 1.4683
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9602 - val_loss: 1.5052
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9307 - val_loss: 1.4676
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0648 - val_loss: 1.4749
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9686 - val_loss: 1.4792
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0090 - val_loss: 1.4780
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0950 - val_loss: 1.4622
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1893 - val_loss: 1.4819
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0647 - val_loss: 1.4781
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1607 - val_loss: 1.4663
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0283 - val_loss: 1.4912
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1101 - val_loss: 1.4636
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1045 - val_loss: 1.4945
# CPU times: total: 3.23 s
# Wall time: 20.6 s

# %%
plt.plot(history_original.history['loss'], label='loss')
plt.plot(history_original.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()


# Comparar Original vs Variación 1
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion1.history['loss'], label='Variación 1 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion1.history['val_loss'], '--', label='Variación 1 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 1')
plt.legend()
plt.show()

# Comparar Original vs Variación 2
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion2.history['loss'], label='Variación 2 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion2.history['val_loss'], '--', label='Variación 2 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 2')
plt.legend()
plt.show()

# Comparar Original vs Variación 3
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion3.history['loss'], label='Variación 3 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion3.history['val_loss'], '--', label='Variación 3 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 3')
plt.legend()
plt.show()

# %%
test_res['dnn_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# variacion 1
test_res['variacion1_model'] = variacion1_model.evaluate(test_X, test_y, verbose=0)


# variacion 2
test_res['variacion2_model'] = variacion2_model.evaluate(test_X, test_y, verbose=0)

# variacion 3
test_res['variacion3_model'] = variacion3_model.evaluate(test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'linear_model': 2.7586874961853027,
#  'dnn_model': 2.175907611846924,
#  'variacion1_model': 3.1564886569976807,
#  'variacion2_model': 2.5538289546966553,
#  'variacion3_model': 2.321040391921997}

# %%
test_pred = dnn_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("Original")
plt.show()

# variacion 1
test_pred = variacion1_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("variacion 1")
plt.show()

# variacion 2
test_pred = variacion2_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("variacion 2")
plt.show()

# variacion 3
test_pred = variacion3_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("variacion 3")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

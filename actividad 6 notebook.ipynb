# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 11-12: Introducción a redes neuronales
#
# - Redes densas
# - Redes para regresión
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy y pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('auto-mpg.data',
                 names=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin'],
                 sep=' ',
                 na_values='?',
                 comment='\t',
                 skipinitialspace=True
                 )

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df=df.drop(["Origin"], axis=1)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 7 columns]

# %% [markdown]
# - MPG: miles per gallon
# - Cylinders: # de cilindros
# - Displacement: volumen desplazado por los pistones
# - Horsepower: caballos de potencia
# - Weight: peso
# - Acceleration: aceleración
# - Model Year: año/modelo
# - Origin: 1:USA, 2:Europa, 3:Japón

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (398, 7)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %% [markdown]
# Separamos los datos en entrenamiento y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 125  20.0          6         198.0        95.0  3102.0          16.5
# 142  26.0          4          79.0        67.0  1963.0          15.5
# 278  31.5          4          89.0        71.0  1990.0          14.9
# 254  20.2          6         200.0        85.0  2965.0          15.8
# 328  30.0          4         146.0        67.0  3250.0          21.8
#
#      Model Year
# 125          74
# 142          74
# 278          78
# 254          78
# 328          80

# %%
test = df.drop(train.index)
test.head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0   18.0          8         307.0       130.0  3504.0          12.0
# 2   18.0          8         318.0       150.0  3436.0          11.0
# 4   17.0          8         302.0       140.0  3449.0          10.5
# 8   14.0          8         455.0       225.0  4425.0          10.0
# 13  14.0          8         455.0       225.0  3086.0          10.0
#
#     Model Year
# 0           70
# 2           70
# 4           70
# 8           70
# 13          70

# %%
print(train.shape)
print(test.shape)
# Out:
# (314, 7)
# (78, 7)

# %% [markdown]
# Realicemos una exploración descriptiva de los datos, calculando inicialmente estadísticas de cada variable continua

# %%
train.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.579299    5.455414    192.562102  103.767516  2959.312102
# std      7.877216    1.691811    103.701434   38.123560   856.880939
# min      9.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.125000    4.000000     98.000000   75.000000  2193.000000
# 50%     23.000000    4.000000    146.000000   94.500000  2764.500000
# 75%     29.375000    8.000000    260.000000  120.000000  3612.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year
# count    314.000000  314.000000
# mean      15.518471   75.964968
# std        2.705097    3.672110
# min        8.000000   70.000000
# 25%       13.900000   73.000000
# 50%       15.500000   76.000000
# 75%       17.000000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Exploremos relaciones bivariadas con pairplot de seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(train)

# %% [markdown]
# Calculemos la matriz de correlacion

# %%
train.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777230     -0.807032   -0.775493 -0.832793
# Cylinders    -0.777230   1.000000      0.950858    0.849237  0.901259
# Displacement -0.807032   0.950858      1.000000    0.893640  0.941913
# Horsepower   -0.775493   0.849237      0.893640    1.000000  0.875157
# Weight       -0.832793   0.901259      0.941913    0.875157  1.000000
# Acceleration  0.389422  -0.488703     -0.523473   -0.672989 -0.402870
# Model Year    0.596816  -0.330668     -0.364236   -0.414065 -0.318231
#
#               Acceleration  Model Year
# MPG               0.389422    0.596816
# Cylinders        -0.488703   -0.330668
# Displacement     -0.523473   -0.364236
# Horsepower       -0.672989   -0.414065
# Weight           -0.402870   -0.318231
# Acceleration      1.000000    0.258013
# Model Year        0.258013    1.000000

# %%
sns.heatmap(train.corr())
# Out:
# <Axes: >

# %% [markdown]
# Seleccionamos ahora las características y las etiquetas (MPG)

# %%
train_X = train.copy()
test_X = test.copy()

# %%
train_y = train_X.pop('MPG')
test_y = test_X.pop('MPG')

# %%
train_X.head()
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74
# 142          4          79.0        67.0  1963.0          15.5          74
# 278          4          89.0        71.0  1990.0          14.9          78
# 254          6         200.0        85.0  2965.0          15.8          78
# 328          4         146.0        67.0  3250.0          21.8          80

# %%
train_y.head()
# Out:
# 125    20.0
# 142    26.0
# 278    31.5
# 254    20.2
# 328    30.0
# Name: MPG, dtype: float64

# %%
train_X.dtypes
# Out:
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model Year        int64
# dtype: object

# %% [markdown]
# Construyamos los modelos usando tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Capa de normalización

# %%
tf.keras.layers.Normalization
# Out:
# keras.src.layers.preprocessing.normalization.Normalization

# %%
norm = tf.keras.layers.Normalization()

# %%
norm.adapt(np.array(train_X))

# %%
norm.mean.numpy()
# Out:
# array([[   5.455414,  192.5621  ,  103.76752 , 2959.312   ,   15.518472,
#           75.964966]], dtype=float32)

# %%
norm.variance.numpy()
# Out:
# array([[2.8531077e+00, 1.0719739e+04, 1.4487772e+03, 7.3190656e+05,
#         7.2942448e+00, 1.3441448e+01]], dtype=float32)

# %%
np.sqrt(norm.variance.numpy())
# Out:
# array([[  1.6891145, 103.53617  ,  38.062805 , 855.5154   ,   2.7007859,
#           3.666258 ]], dtype=float32)

# %%
train_X[:1]
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74

# %%
norm(train_X[:1]).numpy()
# Out:
# array([[ 0.32240927,  0.05252171, -0.23034343,  0.166786  ,  0.36342323,
#         -0.5359595 ]], dtype=float32)

# %% [markdown]
# ## Modelo con múltiples variables de entrada

# %%
linear_model = tf.keras.Sequential([
    norm,
    tf.keras.layers.Dense(units=1)
])

# %%
linear_model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_X,
    train_y,
    epochs=100,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 23.7425 - val_loss: 21.7727
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.9247 - val_loss: 21.0683
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.4088 - val_loss: 20.4097
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.3154 - val_loss: 19.7284
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.1152 - val_loss: 19.0178
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.0332 - val_loss: 18.2775
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 18.4960 - val_loss: 17.6497
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.9871 - val_loss: 17.0341
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.7610 - val_loss: 16.3567
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.3044 - val_loss: 15.5610
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.0924 - val_loss: 14.9413
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.6558 - val_loss: 14.2341
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.4293 - val_loss: 13.5333
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.9990 - val_loss: 12.8023
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.0853 - val_loss: 12.1166
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.1036 - val_loss: 11.4661
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.5478 - val_loss: 10.7416
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5378 - val_loss: 10.0101
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.0501 - val_loss: 9.2324
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.3044 - val_loss: 8.4145
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.4477 - val_loss: 7.6096
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6939 - val_loss: 6.8495
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0850 - val_loss: 6.0316
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6680 - val_loss: 5.1543
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1350 - val_loss: 4.3958
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5652 - val_loss: 3.7467
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7271 - val_loss: 3.0738
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4845 - val_loss: 2.7242
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0099 - val_loss: 2.5604
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8366 - val_loss: 2.4781
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7982 - val_loss: 2.3421
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8266 - val_loss: 2.2897
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6357 - val_loss: 2.2653
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7466 - val_loss: 2.3560
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6069 - val_loss: 2.2277
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9083 - val_loss: 2.2612
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6334 - val_loss: 2.3013
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8174 - val_loss: 2.2664
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6684 - val_loss: 2.2097
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6822 - val_loss: 2.2500
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7179 - val_loss: 2.2228
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5740 - val_loss: 2.2231
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4596 - val_loss: 2.3035
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5954 - val_loss: 2.2889
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8047 - val_loss: 2.2030
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6469 - val_loss: 2.2422
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6346 - val_loss: 2.2453
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5410 - val_loss: 2.2502
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7679 - val_loss: 2.2159
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5708 - val_loss: 2.3646
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4087 - val_loss: 2.2005
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7516 - val_loss: 2.2715
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7079 - val_loss: 2.2575
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6060 - val_loss: 2.2180
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6114 - val_loss: 2.2574
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6350 - val_loss: 2.3179
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5606 - val_loss: 2.2304
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7123 - val_loss: 2.2690
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4904 - val_loss: 2.2893
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6538 - val_loss: 2.2623
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5879 - val_loss: 2.2278
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5785 - val_loss: 2.3607
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5956 - val_loss: 2.2373
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6253 - val_loss: 2.3020
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5659 - val_loss: 2.2590
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5823 - val_loss: 2.2683
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6790 - val_loss: 2.3144
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7119 - val_loss: 2.2798
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3985 - val_loss: 2.2495
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5969 - val_loss: 2.2992
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5948 - val_loss: 2.2707
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6609 - val_loss: 2.2317
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4430 - val_loss: 2.3367
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6273 - val_loss: 2.2669
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6161 - val_loss: 2.2384
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4759 - val_loss: 2.2985
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4878 - val_loss: 2.2959
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6701 - val_loss: 2.2150
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5081 - val_loss: 2.3001
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6035 - val_loss: 2.3016
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5388 - val_loss: 2.2006
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6724 - val_loss: 2.2730
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6897 - val_loss: 2.3401
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7011 - val_loss: 2.2070
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5801 - val_loss: 2.3060
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5923 - val_loss: 2.2457
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3870 - val_loss: 2.3054
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4823 - val_loss: 2.2859
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6431 - val_loss: 2.2350
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6431 - val_loss: 2.3232
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5632 - val_loss: 2.2664
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6890 - val_loss: 2.2919
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4621 - val_loss: 2.2949
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6197 - val_loss: 2.2571
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5725 - val_loss: 2.2679
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4751 - val_loss: 2.2397
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5872 - val_loss: 2.2353
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5980 - val_loss: 2.3636
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4902 - val_loss: 2.2668
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5775 - val_loss: 2.2438
# CPU times: total: 20.6 s
# Wall time: 18.3 s

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res['linear_model'] = linear_model.evaluate(
    test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'h_model': 3.6814887523651123,
#  'dnn_h_model': 3.061788320541382,
#  'variacion1_model': 3.136021137237549,
#  'variacion2_model': 2.999600648880005,
#  'variacion3_model': 2.9899914264678955,
#  'linear_model': 2.74725604057312,
#  'dnn_model': 2.3172435760498047}

# %%
dnn_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# variacion 1
variacion1_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 2
variacion2_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(24, activation='relu'),
      tf.keras.layers.Dense(24, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 3
variacion3_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# %%
dnn_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# variacion 1
variacion1_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 2
variacion2_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 3
variacion3_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
dnn_model.summary()

# variacion 1
variacion1_model.summary()


# variacion 2
variacion2_model.summary()


# variacion 3
variacion3_model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
# %%time
history_original = dnn_model.fit(
  train_X,
  train_y,
  validation_split=0.2,
  epochs=100)

  # variacion 1
history_variacion1 = variacion1_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)


# variacion 2
history_variacion2 = variacion2_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)

# variacion 3
history_variacion3 = variacion3_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 23.6262 - val_loss: 21.8679
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 22.7974 - val_loss: 21.2242
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.7278 - val_loss: 20.4452
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.1757 - val_loss: 19.4390
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.8941 - val_loss: 18.0715
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.8021 - val_loss: 16.2569
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.3203 - val_loss: 14.3101
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.0714 - val_loss: 12.4632
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.1442 - val_loss: 10.2945
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.2310 - val_loss: 7.5459
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.2235 - val_loss: 4.6601
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2775 - val_loss: 4.3821
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4299 - val_loss: 4.1211
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4354 - val_loss: 3.6026
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2806 - val_loss: 3.4757
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0779 - val_loss: 3.1670
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8396 - val_loss: 3.0160
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5250 - val_loss: 2.9180
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4527 - val_loss: 2.7967
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3839 - val_loss: 2.7066
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2287 - val_loss: 2.6219
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2123 - val_loss: 2.5003
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9936 - val_loss: 2.5203
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0426 - val_loss: 2.4504
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8038 - val_loss: 2.3382
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6898 - val_loss: 2.2997
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6868 - val_loss: 2.3393
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5927 - val_loss: 2.2637
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7422 - val_loss: 2.3002
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5060 - val_loss: 2.2678
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5145 - val_loss: 2.1662
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4948 - val_loss: 2.1905
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3983 - val_loss: 2.1634
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4544 - val_loss: 2.1751
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4947 - val_loss: 2.1359
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6327 - val_loss: 2.1229
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3173 - val_loss: 2.1060
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2831 - val_loss: 2.0805
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2631 - val_loss: 2.0605
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2814 - val_loss: 2.0787
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2140 - val_loss: 2.0229
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3430 - val_loss: 2.0199
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1738 - val_loss: 2.0414
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2918 - val_loss: 1.9741
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3146 - val_loss: 2.0284
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3754 - val_loss: 2.0007
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4735 - val_loss: 1.9747
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0920 - val_loss: 1.9892
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2101 - val_loss: 1.9775
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0274 - val_loss: 1.9467
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3899 - val_loss: 1.9562
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1728 - val_loss: 1.9334
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1338 - val_loss: 1.9273
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0944 - val_loss: 1.9789
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0950 - val_loss: 1.9057
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0732 - val_loss: 1.9856
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1530 - val_loss: 1.9091
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0501 - val_loss: 1.9167
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9223 - val_loss: 1.9849
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1250 - val_loss: 1.8744
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9653 - val_loss: 1.9678
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2225 - val_loss: 1.9115
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0850 - val_loss: 1.9048
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0502 - val_loss: 1.9329
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0517 - val_loss: 1.8903
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1668 - val_loss: 1.9430
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0708 - val_loss: 1.9602
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9556 - val_loss: 1.8874
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0381 - val_loss: 1.9108
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8287 - val_loss: 1.8511
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9167 - val_loss: 1.8984
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1105 - val_loss: 1.8650
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9681 - val_loss: 1.8844
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8732 - val_loss: 1.8621
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9665 - val_loss: 1.8996
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9622 - val_loss: 1.8958
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0055 - val_loss: 1.8647
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9355 - val_loss: 1.8208
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9808 - val_loss: 1.8916
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8476 - val_loss: 1.8568
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9592 - val_loss: 1.8694
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7083 - val_loss: 1.8287
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9830 - val_loss: 1.8675
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8587 - val_loss: 1.8435
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8300 - val_loss: 1.8410
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9216 - val_loss: 1.8304
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8054 - val_loss: 1.8675
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8465 - val_loss: 1.7942
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8642 - val_loss: 1.8555
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8560 - val_loss: 1.8803
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0330 - val_loss: 1.8066
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8130 - val_loss: 1.8926
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8536 - val_loss: 1.8232
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6701 - val_loss: 1.8956
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7631 - val_loss: 1.8705
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9601 - val_loss: 1.8678
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8686 - val_loss: 1.8294
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8908 - val_loss: 1.8696
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7284 - val_loss: 1.8616
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5648 - val_loss: 1.9008
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 23.9902 - val_loss: 22.5420
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24.2050 - val_loss: 22.1901
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.3921 - val_loss: 21.8433
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.1402 - val_loss: 21.4840
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.7308 - val_loss: 21.0770
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.5910 - val_loss: 20.5863
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.8363 - val_loss: 19.9960
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.3083 - val_loss: 19.2890
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.3604 - val_loss: 18.4299
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.9680 - val_loss: 17.3861
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.6893 - val_loss: 16.1655
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.1506 - val_loss: 14.9905
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.5365 - val_loss: 13.8898
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.1965 - val_loss: 12.8487
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.4015 - val_loss: 11.6738
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.4786 - val_loss: 10.3031
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.6697 - val_loss: 8.7480
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.5690 - val_loss: 6.9478
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9259 - val_loss: 5.2800
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.0038 - val_loss: 4.9771
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6105 - val_loss: 4.8573
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2587 - val_loss: 4.6664
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9427 - val_loss: 4.4827
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4382 - val_loss: 4.3337
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0680 - val_loss: 4.1746
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.2088 - val_loss: 4.0003
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7764 - val_loss: 3.8734
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2534 - val_loss: 3.7130
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3253 - val_loss: 3.6094
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0067 - val_loss: 3.5055
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0310 - val_loss: 3.4039
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8768 - val_loss: 3.2946
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0142 - val_loss: 3.2026
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.6667 - val_loss: 3.1279
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6065 - val_loss: 3.0662
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4415 - val_loss: 2.9976
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4276 - val_loss: 2.9434
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2013 - val_loss: 2.8729
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4334 - val_loss: 2.8155
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9869 - val_loss: 2.7245
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8410 - val_loss: 2.6282
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7865 - val_loss: 2.5595
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9984 - val_loss: 2.4644
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9201 - val_loss: 2.4072
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6732 - val_loss: 2.3315
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7570 - val_loss: 2.2699
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7790 - val_loss: 2.2124
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8996 - val_loss: 2.1544
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6426 - val_loss: 2.1487
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6371 - val_loss: 2.0755
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5401 - val_loss: 2.0470
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4611 - val_loss: 1.9706
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5163 - val_loss: 1.9486
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3709 - val_loss: 1.9508
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2648 - val_loss: 1.8996
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2130 - val_loss: 1.8712
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4514 - val_loss: 1.8612
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1953 - val_loss: 1.8257
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1691 - val_loss: 1.8218
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1592 - val_loss: 1.8112
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2477 - val_loss: 1.8013
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2880 - val_loss: 1.7810
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1164 - val_loss: 1.7829
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0426 - val_loss: 1.7804
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2045 - val_loss: 1.7749
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0481 - val_loss: 1.7773
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9645 - val_loss: 1.7751
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2252 - val_loss: 1.7585
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1838 - val_loss: 1.7363
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1680 - val_loss: 1.7623
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1683 - val_loss: 1.7516
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2192 - val_loss: 1.7370
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2294 - val_loss: 1.7395
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0288 - val_loss: 1.7172
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0895 - val_loss: 1.7344
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0946 - val_loss: 1.7174
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0457 - val_loss: 1.7268
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1483 - val_loss: 1.7016
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1572 - val_loss: 1.7142
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2290 - val_loss: 1.7068
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0651 - val_loss: 1.7235
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0572 - val_loss: 1.6894
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0518 - val_loss: 1.7075
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0122 - val_loss: 1.7462
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0703 - val_loss: 1.6756
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9309 - val_loss: 1.7029
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0505 - val_loss: 1.6883
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1451 - val_loss: 1.6786
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9764 - val_loss: 1.6729
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9935 - val_loss: 1.7108
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8561 - val_loss: 1.6614
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8832 - val_loss: 1.6750
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0464 - val_loss: 1.6988
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9161 - val_loss: 1.6514
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9573 - val_loss: 1.7034
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9657 - val_loss: 1.6528
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1039 - val_loss: 1.6705
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9941 - val_loss: 1.6953
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9841 - val_loss: 1.6540
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0773 - val_loss: 1.6573
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 23.4523 - val_loss: 21.5478
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.2188 - val_loss: 21.1472
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.7185 - val_loss: 20.7132
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.0449 - val_loss: 20.2280
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.0156 - val_loss: 19.6831
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.9029 - val_loss: 19.0715
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 20.3633 - val_loss: 18.3768
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 20.4859 - val_loss: 17.6441
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.9381 - val_loss: 16.9615
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 18.1966 - val_loss: 16.2828
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.7924 - val_loss: 15.7220
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.8540 - val_loss: 15.1524
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.7938 - val_loss: 14.5534
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.0307 - val_loss: 13.8704
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.2553 - val_loss: 13.0574
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.9219 - val_loss: 12.1381
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.3405 - val_loss: 11.0786
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.2963 - val_loss: 9.8864
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.1108 - val_loss: 8.5606
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0071 - val_loss: 7.0982
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.5890 - val_loss: 5.7117
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.2285 - val_loss: 4.6043
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5144 - val_loss: 4.0880
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7402 - val_loss: 3.9915
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.2585 - val_loss: 3.8505
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7297 - val_loss: 3.6943
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7690 - val_loss: 3.5235
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.6038 - val_loss: 3.3938
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2021 - val_loss: 3.2769
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2753 - val_loss: 3.1600
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.0876 - val_loss: 3.0487
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9481 - val_loss: 2.9313
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0282 - val_loss: 2.8459
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6304 - val_loss: 2.7812
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5477 - val_loss: 2.7162
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4616 - val_loss: 2.6135
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4618 - val_loss: 2.5271
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2388 - val_loss: 2.4677
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1405 - val_loss: 2.4281
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0797 - val_loss: 2.3521
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1512 - val_loss: 2.2828
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8412 - val_loss: 2.2623
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7865 - val_loss: 2.2302
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6545 - val_loss: 2.1839
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6042 - val_loss: 2.1600
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8227 - val_loss: 2.1235
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5279 - val_loss: 2.1475
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5931 - val_loss: 2.1126
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5835 - val_loss: 2.0714
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3645 - val_loss: 2.0761
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5098 - val_loss: 2.0659
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5185 - val_loss: 2.0646
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3696 - val_loss: 1.9988
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4664 - val_loss: 1.9832
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4530 - val_loss: 2.0093
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2123 - val_loss: 1.9518
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3956 - val_loss: 1.9660
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3364 - val_loss: 1.9597
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2528 - val_loss: 1.9025
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3404 - val_loss: 1.9313
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4678 - val_loss: 1.8899
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3966 - val_loss: 1.8898
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4233 - val_loss: 1.9111
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2803 - val_loss: 1.8663
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3128 - val_loss: 1.8696
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2432 - val_loss: 1.8776
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1106 - val_loss: 1.8363
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1872 - val_loss: 1.8357
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3332 - val_loss: 1.8770
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1350 - val_loss: 1.8002
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3595 - val_loss: 1.7918
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3578 - val_loss: 1.8333
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1687 - val_loss: 1.8425
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0590 - val_loss: 1.7827
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3900 - val_loss: 1.7921
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2033 - val_loss: 1.8091
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2443 - val_loss: 1.7780
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2475 - val_loss: 1.7987
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1457 - val_loss: 1.7631
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2764 - val_loss: 1.7748
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0775 - val_loss: 1.7645
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0668 - val_loss: 1.7592
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2516 - val_loss: 1.7655
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9738 - val_loss: 1.7386
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0066 - val_loss: 1.7465
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2416 - val_loss: 1.7763
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0420 - val_loss: 1.7304
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0777 - val_loss: 1.7369
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0257 - val_loss: 1.7137
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0780 - val_loss: 1.7329
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2593 - val_loss: 1.7218
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1981 - val_loss: 1.7218
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1859 - val_loss: 1.7274
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9786 - val_loss: 1.7153
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1655 - val_loss: 1.7512
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9273 - val_loss: 1.7199
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9532 - val_loss: 1.7161
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9745 - val_loss: 1.7491
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0745 - val_loss: 1.6900
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0401 - val_loss: 1.7401
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 24.2133 - val_loss: 22.5100
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.0746 - val_loss: 22.3089
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.7051 - val_loss: 22.1085
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.2308 - val_loss: 21.8991
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.3012 - val_loss: 21.6761
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.2264 - val_loss: 21.4312
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.0928 - val_loss: 21.1619
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 21.9721 - val_loss: 20.8569
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.0527 - val_loss: 20.5125
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.9154 - val_loss: 20.1263
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.5583 - val_loss: 19.6863
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.8668 - val_loss: 19.1712
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.2584 - val_loss: 18.5627
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.9061 - val_loss: 17.8556
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.0207 - val_loss: 17.0530
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.8917 - val_loss: 16.2112
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.6589 - val_loss: 15.4105
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.0212 - val_loss: 14.6001
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 16.6160 - val_loss: 13.8335
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 15.2439 - val_loss: 13.0885
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 13.9177 - val_loss: 12.2918
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.6613 - val_loss: 11.4172
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.8928 - val_loss: 10.4535
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.9809 - val_loss: 9.4326
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.4525 - val_loss: 8.3843
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.7815 - val_loss: 7.4450
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4096 - val_loss: 6.6775
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.2064 - val_loss: 6.1336
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.6560 - val_loss: 5.8783
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5654 - val_loss: 5.7748
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5280 - val_loss: 5.6744
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8884 - val_loss: 5.5836
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1776 - val_loss: 5.4783
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.1719 - val_loss: 5.3590
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6281 - val_loss: 5.2521
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6277 - val_loss: 5.1548
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5815 - val_loss: 5.0558
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5693 - val_loss: 4.9516
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3139 - val_loss: 4.8598
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3884 - val_loss: 4.7729
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0075 - val_loss: 4.6770
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1993 - val_loss: 4.5780
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9125 - val_loss: 4.4820
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7572 - val_loss: 4.3925
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5396 - val_loss: 4.2955
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5764 - val_loss: 4.1965
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8678 - val_loss: 4.1137
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4223 - val_loss: 4.0208
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3068 - val_loss: 3.9264
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2105 - val_loss: 3.8201
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9728 - val_loss: 3.7267
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8727 - val_loss: 3.6222
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.8189 - val_loss: 3.5192
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5793 - val_loss: 3.4234
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.9848 - val_loss: 3.3238
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7858 - val_loss: 3.2464
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4675 - val_loss: 3.1683
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5205 - val_loss: 3.0994
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4202 - val_loss: 3.0461
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1434 - val_loss: 2.9511
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2087 - val_loss: 2.8579
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1125 - val_loss: 2.7941
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1699 - val_loss: 2.7187
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1982 - val_loss: 2.6523
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8356 - val_loss: 2.5912
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8414 - val_loss: 2.5323
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7341 - val_loss: 2.4579
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8153 - val_loss: 2.4022
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7024 - val_loss: 2.3415
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7435 - val_loss: 2.3153
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7008 - val_loss: 2.2642
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5737 - val_loss: 2.1997
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7466 - val_loss: 2.1717
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3706 - val_loss: 2.1479
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3826 - val_loss: 2.1048
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6160 - val_loss: 2.0480
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3213 - val_loss: 2.0297
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3756 - val_loss: 2.0071
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5041 - val_loss: 1.9506
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4559 - val_loss: 1.9166
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3023 - val_loss: 1.8901
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5648 - val_loss: 1.8664
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2353 - val_loss: 1.8304
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2546 - val_loss: 1.8106
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0768 - val_loss: 1.7860
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3453 - val_loss: 1.7684
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0368 - val_loss: 1.7492
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1586 - val_loss: 1.7238
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2504 - val_loss: 1.7130
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4659 - val_loss: 1.7134
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2701 - val_loss: 1.6906
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2347 - val_loss: 1.6857
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2028 - val_loss: 1.6771
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1966 - val_loss: 1.6696
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1574 - val_loss: 1.6622
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2101 - val_loss: 1.6539
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3510 - val_loss: 1.6987
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2111 - val_loss: 1.6421
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1592 - val_loss: 1.6460
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0963 - val_loss: 1.6615
# CPU times: total: 1min 33s
# Wall time: 1min 23s

# %%
plt.plot(history_original.history['loss'], label='loss')
plt.plot(history_original.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()


# Comparar Original vs Variación 1
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion1.history['loss'], label='Variación 1 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion1.history['val_loss'], '--', label='Variación 1 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 1')
plt.legend()
plt.show()

# Comparar Original vs Variación 2
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion2.history['loss'], label='Variación 2 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion2.history['val_loss'], '--', label='Variación 2 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 2')
plt.legend()
plt.show()

# Comparar Original vs Variación 3
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion3.history['loss'], label='Variación 3 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion3.history['val_loss'], '--', label='Variación 3 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 3')
plt.legend()
plt.show()

# %%
test_res['dnn_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# variacion 1
test_res['variacion1_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)


# variacion 2
test_res['variacion2_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# variacion 3
test_res['variacion3_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'h_model': 3.6814887523651123,
#  'dnn_h_model': 3.061788320541382,
#  'variacion1_model': 2.283916473388672,
#  'variacion2_model': 2.283916473388672,
#  'variacion3_model': 2.283916473388672,
#  'linear_model': 2.74725604057312,
#  'dnn_model': 2.283916473388672}

# %%
test_pred = dnn_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()

# variacion 1
test_pred = variacion1_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()

# variacion 2
test_pred = variacion2_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()

# variacion 3
test_pred = variacion3_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

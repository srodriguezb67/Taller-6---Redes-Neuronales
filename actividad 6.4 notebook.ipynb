# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 11-12: Introducción a redes neuronales
#
# - Redes densas
# - Redes para regresión
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy y pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('auto-mpg.data',
                 names=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin'],
                 sep=' ',
                 na_values='?',
                 comment='\t',
                 skipinitialspace=True
                 )

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df=df.drop(["Origin"], axis=1)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 7 columns]

# %% [markdown]
# - MPG: miles per gallon
# - Cylinders: # de cilindros
# - Displacement: volumen desplazado por los pistones
# - Horsepower: caballos de potencia
# - Weight: peso
# - Acceleration: aceleración
# - Model Year: año/modelo
# - Origin: 1:USA, 2:Europa, 3:Japón

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (398, 7)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %% [markdown]
# Separamos los datos en entrenamiento y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 125  20.0          6         198.0        95.0  3102.0          16.5
# 142  26.0          4          79.0        67.0  1963.0          15.5
# 278  31.5          4          89.0        71.0  1990.0          14.9
# 254  20.2          6         200.0        85.0  2965.0          15.8
# 328  30.0          4         146.0        67.0  3250.0          21.8
#
#      Model Year
# 125          74
# 142          74
# 278          78
# 254          78
# 328          80

# %%
test = df.drop(train.index)
test.head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0   18.0          8         307.0       130.0  3504.0          12.0
# 2   18.0          8         318.0       150.0  3436.0          11.0
# 4   17.0          8         302.0       140.0  3449.0          10.5
# 8   14.0          8         455.0       225.0  4425.0          10.0
# 13  14.0          8         455.0       225.0  3086.0          10.0
#
#     Model Year
# 0           70
# 2           70
# 4           70
# 8           70
# 13          70

# %%
print(train.shape)
print(test.shape)
# Out:
# (314, 7)
# (78, 7)

# %% [markdown]
# Realicemos una exploración descriptiva de los datos, calculando inicialmente estadísticas de cada variable continua

# %%
train.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.579299    5.455414    192.562102  103.767516  2959.312102
# std      7.877216    1.691811    103.701434   38.123560   856.880939
# min      9.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.125000    4.000000     98.000000   75.000000  2193.000000
# 50%     23.000000    4.000000    146.000000   94.500000  2764.500000
# 75%     29.375000    8.000000    260.000000  120.000000  3612.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year
# count    314.000000  314.000000
# mean      15.518471   75.964968
# std        2.705097    3.672110
# min        8.000000   70.000000
# 25%       13.900000   73.000000
# 50%       15.500000   76.000000
# 75%       17.000000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Exploremos relaciones bivariadas con pairplot de seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(train)

# %% [markdown]
# Calculemos la matriz de correlacion

# %%
train.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777230     -0.807032   -0.775493 -0.832793
# Cylinders    -0.777230   1.000000      0.950858    0.849237  0.901259
# Displacement -0.807032   0.950858      1.000000    0.893640  0.941913
# Horsepower   -0.775493   0.849237      0.893640    1.000000  0.875157
# Weight       -0.832793   0.901259      0.941913    0.875157  1.000000
# Acceleration  0.389422  -0.488703     -0.523473   -0.672989 -0.402870
# Model Year    0.596816  -0.330668     -0.364236   -0.414065 -0.318231
#
#               Acceleration  Model Year
# MPG               0.389422    0.596816
# Cylinders        -0.488703   -0.330668
# Displacement     -0.523473   -0.364236
# Horsepower       -0.672989   -0.414065
# Weight           -0.402870   -0.318231
# Acceleration      1.000000    0.258013
# Model Year        0.258013    1.000000

# %%
sns.heatmap(train.corr())
# Out:
# <Axes: >

# %% [markdown]
# Seleccionamos ahora las características y las etiquetas (MPG)

# %%
train_X = train.copy()
test_X = test.copy()

# %%
train_y = train_X.pop('MPG')
test_y = test_X.pop('MPG')

# %%
train_X.head()
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74
# 142          4          79.0        67.0  1963.0          15.5          74
# 278          4          89.0        71.0  1990.0          14.9          78
# 254          6         200.0        85.0  2965.0          15.8          78
# 328          4         146.0        67.0  3250.0          21.8          80

# %%
train_y.head()
# Out:
# 125    20.0
# 142    26.0
# 278    31.5
# 254    20.2
# 328    30.0
# Name: MPG, dtype: float64

# %%
train_X.dtypes
# Out:
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model Year        int64
# dtype: object

# %% [markdown]
# Construyamos los modelos usando tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Capa de normalización

# %%
tf.keras.layers.Normalization
# Out:
# keras.src.layers.preprocessing.normalization.Normalization

# %%
norm = tf.keras.layers.Normalization()

# %%
norm.adapt(np.array(train_X))

# %%
norm.mean.numpy()
# Out:
# array([[   5.455414,  192.5621  ,  103.76752 , 2959.312   ,   15.518472,
#           75.964966]], dtype=float32)

# %%
norm.variance.numpy()
# Out:
# array([[2.8531077e+00, 1.0719739e+04, 1.4487772e+03, 7.3190656e+05,
#         7.2942448e+00, 1.3441448e+01]], dtype=float32)

# %%
np.sqrt(norm.variance.numpy())
# Out:
# array([[  1.6891145, 103.53617  ,  38.062805 , 855.5154   ,   2.7007859,
#           3.666258 ]], dtype=float32)

# %%
train_X[:1]
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74

# %%
norm(train_X[:1]).numpy()
# Out:
# array([[ 0.32240927,  0.05252171, -0.23034343,  0.166786  ,  0.36342323,
#         -0.5359595 ]], dtype=float32)

# %% [markdown]
# ## Modelo con múltiples variables de entrada

# %%
linear_model = tf.keras.Sequential([
    norm,
    tf.keras.layers.Dense(units=1)
])

# %%
linear_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (314, 6)               │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_X,
    train_y,
    epochs=100,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 23.6931 - val_loss: 21.8909
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 22.6111 - val_loss: 21.2286
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.8663 - val_loss: 20.5371
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 21.3011 - val_loss: 19.9321
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20.4971 - val_loss: 19.2210
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19.1512 - val_loss: 18.4630
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 18.5966 - val_loss: 17.7666
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.4567 - val_loss: 17.1453
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16.7214 - val_loss: 16.4950
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15.8341 - val_loss: 15.7808
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.4335 - val_loss: 15.0846
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.5208 - val_loss: 14.4272
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.5633 - val_loss: 13.7205
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 13.1960 - val_loss: 12.9930
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 11.9953 - val_loss: 12.3055
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 11.1277 - val_loss: 11.6316
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 10.0973 - val_loss: 10.9395
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 10.0315 - val_loss: 10.1462
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.0150 - val_loss: 9.3317
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.2590 - val_loss: 8.5491
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.5976 - val_loss: 7.7179
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.8044 - val_loss: 6.9241
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.3386 - val_loss: 6.0315
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.4298 - val_loss: 5.1484
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0362 - val_loss: 4.4879
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3600 - val_loss: 3.7261
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.9569 - val_loss: 3.1537
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.3552 - val_loss: 2.6757
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1006 - val_loss: 2.5515
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.0338 - val_loss: 2.3932
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8971 - val_loss: 2.3097
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.8901 - val_loss: 2.2589
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.7787 - val_loss: 2.2550
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.9319 - val_loss: 2.2877
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7265 - val_loss: 2.2385
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4474 - val_loss: 2.2126
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7404 - val_loss: 2.2194
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7035 - val_loss: 2.2454
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6200 - val_loss: 2.2808
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8250 - val_loss: 2.2225
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8404 - val_loss: 2.2235
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9812 - val_loss: 2.3345
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5565 - val_loss: 2.2385
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5274 - val_loss: 2.2162
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4859 - val_loss: 2.3162
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4106 - val_loss: 2.1958
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4613 - val_loss: 2.3162
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8165 - val_loss: 2.2678
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7150 - val_loss: 2.2230
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8043 - val_loss: 2.2520
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6879 - val_loss: 2.2915
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6649 - val_loss: 2.2589
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.7260 - val_loss: 2.2627
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4549 - val_loss: 2.3072
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5929 - val_loss: 2.2371
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7513 - val_loss: 2.2589
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7564 - val_loss: 2.2681
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6002 - val_loss: 2.2736
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5769 - val_loss: 2.2792
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4487 - val_loss: 2.2638
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4416 - val_loss: 2.2427
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4106 - val_loss: 2.3089
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5065 - val_loss: 2.2345
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6326 - val_loss: 2.3332
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4303 - val_loss: 2.2568
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5770 - val_loss: 2.2652
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5245 - val_loss: 2.3176
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6036 - val_loss: 2.2446
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.7079 - val_loss: 2.3104
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7134 - val_loss: 2.2463
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6324 - val_loss: 2.2938
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.6303 - val_loss: 2.2404
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6651 - val_loss: 2.2796
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5255 - val_loss: 2.2463
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6151 - val_loss: 2.2580
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.7034 - val_loss: 2.2389
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6481 - val_loss: 2.2427
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5269 - val_loss: 2.2185
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5412 - val_loss: 2.4124
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7630 - val_loss: 2.2733
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6343 - val_loss: 2.2042
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5145 - val_loss: 2.2945
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5820 - val_loss: 2.3145
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5897 - val_loss: 2.2761
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4573 - val_loss: 2.2452
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.7851 - val_loss: 2.3476
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5956 - val_loss: 2.2718
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4384 - val_loss: 2.2407
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.4639 - val_loss: 2.2877
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5330 - val_loss: 2.2858
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8567 - val_loss: 2.3855
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5576 - val_loss: 2.1962
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4665 - val_loss: 2.2862
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6877 - val_loss: 2.3370
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5207 - val_loss: 2.2243
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4987 - val_loss: 2.2148
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.6663 - val_loss: 2.3455
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7897 - val_loss: 2.2887
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6653 - val_loss: 2.1733
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7378 - val_loss: 2.3155
# CPU times: total: 27.1 s
# Wall time: 23.9 s

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res = {}
test_res['linear_model'] = linear_model.evaluate(
    test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'linear_model': 2.7763447761535645}

# %%
dnn_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# variacion 1
variacion1_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 2
variacion2_model= tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 3
variacion3_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# %%
dnn_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# variacion 1
variacion1_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 2
variacion2_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 3
variacion3_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
dnn_model.summary()

# variacion 1
variacion1_model.summary()


# variacion 2
variacion2_model.summary()


# variacion 3
variacion3_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
# %%time
history_original = dnn_model.fit(
  train_X,
  train_y,
  validation_split=0.2,
  epochs=100)

  # variacion 1
history_variacion1 = variacion1_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)


# variacion 2
history_variacion2 = variacion2_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)

# variacion 3
history_variacion3 = variacion3_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 23.4208 - val_loss: 21.7735
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 22.3612 - val_loss: 21.1843
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.8261 - val_loss: 20.4341
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.6270 - val_loss: 19.4159
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.0375 - val_loss: 17.9917
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19.1191 - val_loss: 16.2484
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.6475 - val_loss: 14.4038
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.4442 - val_loss: 12.6878
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 12.7623 - val_loss: 10.7611
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 11.2309 - val_loss: 8.2193
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2887 - val_loss: 5.4480
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4836 - val_loss: 4.7854
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.6508 - val_loss: 4.7395
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0354 - val_loss: 4.1814
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4916 - val_loss: 4.0242
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.1597 - val_loss: 3.8159
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.0036 - val_loss: 3.6180
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.8929 - val_loss: 3.4609
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7548 - val_loss: 3.3230
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.5599 - val_loss: 3.2029
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7548 - val_loss: 3.0698
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.6826 - val_loss: 2.9892
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.1134 - val_loss: 2.9069
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2179 - val_loss: 2.8039
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3266 - val_loss: 2.6980
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0389 - val_loss: 2.6424
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1023 - val_loss: 2.5770
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9860 - val_loss: 2.4921
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6596 - val_loss: 2.4596
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7540 - val_loss: 2.4240
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5642 - val_loss: 2.3320
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5675 - val_loss: 2.3272
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6238 - val_loss: 2.2451
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7933 - val_loss: 2.1720
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4044 - val_loss: 2.2615
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5418 - val_loss: 2.1656
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4395 - val_loss: 2.1137
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4149 - val_loss: 2.1750
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3134 - val_loss: 2.1101
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4940 - val_loss: 2.0608
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4804 - val_loss: 2.0805
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2689 - val_loss: 2.0838
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4721 - val_loss: 2.0264
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3595 - val_loss: 2.0279
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4292 - val_loss: 2.0533
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1555 - val_loss: 2.0110
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3489 - val_loss: 2.0264
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3712 - val_loss: 2.0116
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1576 - val_loss: 1.9594
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.1823 - val_loss: 1.9961
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3527 - val_loss: 1.9970
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4377 - val_loss: 1.9652
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1434 - val_loss: 1.9603
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2859 - val_loss: 1.9270
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3306 - val_loss: 1.9211
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.1429 - val_loss: 1.9506
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0701 - val_loss: 1.9429
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2113 - val_loss: 1.9406
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1229 - val_loss: 1.9450
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2005 - val_loss: 1.9223
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.1972 - val_loss: 1.9671
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0673 - val_loss: 1.8773
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0773 - val_loss: 1.9302
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1380 - val_loss: 1.9253
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1344 - val_loss: 1.9043
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1072 - val_loss: 1.9059
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1707 - val_loss: 1.9002
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0324 - val_loss: 1.8828
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0593 - val_loss: 1.8952
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.0849 - val_loss: 1.8927
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.1205 - val_loss: 1.8932
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2179 - val_loss: 1.8977
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1059 - val_loss: 1.8432
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0490 - val_loss: 1.8918
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8589 - val_loss: 1.8826
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0148 - val_loss: 1.8620
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9146 - val_loss: 1.8586
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.0054 - val_loss: 1.8577
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1725 - val_loss: 1.8805
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9072 - val_loss: 1.8490
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0610 - val_loss: 1.8817
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9616 - val_loss: 1.8315
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0447 - val_loss: 1.8458
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9362 - val_loss: 1.8583
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7724 - val_loss: 1.8288
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9173 - val_loss: 1.8604
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9144 - val_loss: 1.8257
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9567 - val_loss: 1.8263
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1785 - val_loss: 1.8277
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0467 - val_loss: 1.8121
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8761 - val_loss: 1.8122
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9723 - val_loss: 1.8596
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8917 - val_loss: 1.7655
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8169 - val_loss: 1.8483
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1707 - val_loss: 1.8041
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8713 - val_loss: 1.8033
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8494 - val_loss: 1.7658
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.7978 - val_loss: 1.8252
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9159 - val_loss: 1.7648
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8622 - val_loss: 1.8306
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 23.9047 - val_loss: 22.0321
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23.1695 - val_loss: 21.7831
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 23.0841 - val_loss: 21.5266
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 23.5188 - val_loss: 21.2578
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.3538 - val_loss: 20.9738
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.3224 - val_loss: 20.6680
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.9085 - val_loss: 20.3411
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.9281 - val_loss: 19.9919
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.9097 - val_loss: 19.6224
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.1295 - val_loss: 19.2167
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.3157 - val_loss: 18.7925
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.7522 - val_loss: 18.3355
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.3783 - val_loss: 17.8540
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.9221 - val_loss: 17.3400
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.1641 - val_loss: 16.8392
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 18.8601 - val_loss: 16.3820
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 17.9018 - val_loss: 15.9349
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.7182 - val_loss: 15.4976
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.3276 - val_loss: 15.1016
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 16.7536 - val_loss: 14.7126
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.3888 - val_loss: 14.3229
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.0335 - val_loss: 13.9237
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.8254 - val_loss: 13.5102
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.6048 - val_loss: 13.0616
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.6351 - val_loss: 12.5869
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.1700 - val_loss: 12.0949
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.8467 - val_loss: 11.5777
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.1110 - val_loss: 11.0304
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.1830 - val_loss: 10.4575
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 11.8748 - val_loss: 9.8480
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.6317 - val_loss: 9.2204
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.9962 - val_loss: 8.5708
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0498 - val_loss: 7.9130
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.6990 - val_loss: 7.3166
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.4022 - val_loss: 6.7379
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.4737 - val_loss: 6.2314
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.1556 - val_loss: 5.8037
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5752 - val_loss: 5.5293
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1165 - val_loss: 5.3557
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9575 - val_loss: 5.2347
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.7862 - val_loss: 5.1352
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.4407 - val_loss: 5.0532
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.4416 - val_loss: 4.9730
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2948 - val_loss: 4.8991
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7013 - val_loss: 4.8222
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.1310 - val_loss: 4.7495
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3791 - val_loss: 4.6715
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5280 - val_loss: 4.5892
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0230 - val_loss: 4.5096
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.7449 - val_loss: 4.4340
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1623 - val_loss: 4.3612
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6576 - val_loss: 4.2913
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0282 - val_loss: 4.2143
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5198 - val_loss: 4.1374
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8851 - val_loss: 4.0644
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3047 - val_loss: 3.9972
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1179 - val_loss: 3.9309
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.1692 - val_loss: 3.8618
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2340 - val_loss: 3.7914
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9655 - val_loss: 3.7199
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.1992 - val_loss: 3.6522
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.0757 - val_loss: 3.5842
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7877 - val_loss: 3.5242
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.0086 - val_loss: 3.4578
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9033 - val_loss: 3.3819
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.8356 - val_loss: 3.3171
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7892 - val_loss: 3.2625
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6355 - val_loss: 3.2266
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6873 - val_loss: 3.1660
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7652 - val_loss: 3.1031
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3540 - val_loss: 3.0542
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3882 - val_loss: 3.0010
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2749 - val_loss: 2.9510
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1928 - val_loss: 2.9064
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3673 - val_loss: 2.8706
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4275 - val_loss: 2.8276
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0736 - val_loss: 2.7849
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0685 - val_loss: 2.7292
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0737 - val_loss: 2.7046
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8681 - val_loss: 2.6401
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1580 - val_loss: 2.6075
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9406 - val_loss: 2.5582
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.7162 - val_loss: 2.5122
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9635 - val_loss: 2.4683
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8342 - val_loss: 2.4302
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6100 - val_loss: 2.3891
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6483 - val_loss: 2.3740
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5144 - val_loss: 2.3472
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6154 - val_loss: 2.2872
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7066 - val_loss: 2.2575
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4606 - val_loss: 2.2113
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5829 - val_loss: 2.1610
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6659 - val_loss: 2.1230
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5655 - val_loss: 2.1042
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5139 - val_loss: 2.1007
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5084 - val_loss: 2.0477
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3065 - val_loss: 2.0329
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3494 - val_loss: 2.0067
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4926 - val_loss: 1.9772
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3266 - val_loss: 1.9571
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - loss: 23.9230 - val_loss: 21.5500
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.6865 - val_loss: 20.3926
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.9489 - val_loss: 18.5300
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.5966 - val_loss: 15.5594
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.6465 - val_loss: 12.5079
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 12.7691 - val_loss: 8.8165
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7976 - val_loss: 4.7658
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.8090 - val_loss: 4.1839
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8109 - val_loss: 3.6393
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4083 - val_loss: 3.1156
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7555 - val_loss: 3.0078
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5947 - val_loss: 2.8618
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5971 - val_loss: 2.6466
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5064 - val_loss: 2.7339
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2773 - val_loss: 2.4721
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0976 - val_loss: 2.4529
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2551 - val_loss: 2.3315
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9035 - val_loss: 2.4102
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8908 - val_loss: 2.2493
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8159 - val_loss: 2.2681
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8870 - val_loss: 2.2123
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.6230 - val_loss: 2.1364
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5535 - val_loss: 2.2518
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6349 - val_loss: 2.1539
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4754 - val_loss: 2.0601
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6233 - val_loss: 2.1150
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6114 - val_loss: 2.1049
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4491 - val_loss: 2.1098
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1407 - val_loss: 2.0873
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4215 - val_loss: 2.0974
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4613 - val_loss: 2.0628
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2887 - val_loss: 2.1353
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2136 - val_loss: 2.1053
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3282 - val_loss: 2.1164
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1793 - val_loss: 2.0624
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2644 - val_loss: 2.0502
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2990 - val_loss: 2.0730
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2030 - val_loss: 2.1127
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2478 - val_loss: 1.9872
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1152 - val_loss: 2.1793
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9961 - val_loss: 2.0759
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.9132 - val_loss: 2.0459
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0911 - val_loss: 2.0337
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2160 - val_loss: 2.0762
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9671 - val_loss: 2.0034
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2719 - val_loss: 2.0176
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1512 - val_loss: 2.0678
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9796 - val_loss: 1.9889
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9871 - val_loss: 2.0655
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9449 - val_loss: 1.9713
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9033 - val_loss: 2.0579
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9389 - val_loss: 1.9511
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0681 - val_loss: 2.0648
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0295 - val_loss: 1.9373
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9524 - val_loss: 2.0185
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0530 - val_loss: 1.8873
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9204 - val_loss: 2.0708
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9938 - val_loss: 1.8865
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1185 - val_loss: 1.9721
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0896 - val_loss: 2.0141
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.0793 - val_loss: 1.8894
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8646 - val_loss: 2.1479
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0856 - val_loss: 1.8644
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8601 - val_loss: 2.0630
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9770 - val_loss: 1.8986
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8928 - val_loss: 2.0792
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8494 - val_loss: 1.8945
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8377 - val_loss: 1.9092
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9244 - val_loss: 1.8719
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7104 - val_loss: 1.9084
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6393 - val_loss: 1.8811
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0238 - val_loss: 1.8779
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8448 - val_loss: 1.8443
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7707 - val_loss: 1.8285
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7771 - val_loss: 1.9179
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8211 - val_loss: 1.8517
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7738 - val_loss: 1.9634
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7456 - val_loss: 1.8627
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8025 - val_loss: 2.0272
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7539 - val_loss: 1.8574
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.7264 - val_loss: 1.9076
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6907 - val_loss: 1.8725
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7084 - val_loss: 1.8416
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5701 - val_loss: 1.8817
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7504 - val_loss: 2.0357
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6955 - val_loss: 1.8521
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6277 - val_loss: 2.0341
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6263 - val_loss: 2.0084
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7627 - val_loss: 1.9421
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6831 - val_loss: 1.8871
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6240 - val_loss: 1.9817
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7495 - val_loss: 1.8867
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6600 - val_loss: 1.9580
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6671 - val_loss: 1.8579
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6714 - val_loss: 1.9231
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5487 - val_loss: 2.0580
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7847 - val_loss: 1.8672
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5666 - val_loss: 1.9147
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6788 - val_loss: 1.9929
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6496 - val_loss: 1.9291
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - loss: 23.0859 - val_loss: 21.6731
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.0682 - val_loss: 20.2763
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.1189 - val_loss: 17.2400
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.9849 - val_loss: 12.0069
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.8633 - val_loss: 7.4655
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.8233 - val_loss: 5.4454
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.3792 - val_loss: 3.8118
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4930 - val_loss: 3.3039
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7710 - val_loss: 3.0713
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6305 - val_loss: 3.0085
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5494 - val_loss: 2.8238
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.5353 - val_loss: 2.6644
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3023 - val_loss: 2.5969
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0655 - val_loss: 2.5942
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8761 - val_loss: 2.4379
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1016 - val_loss: 2.3788
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5538 - val_loss: 2.2723
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7150 - val_loss: 2.3206
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6199 - val_loss: 2.2146
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7253 - val_loss: 2.3432
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4882 - val_loss: 2.1949
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3199 - val_loss: 2.1466
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7438 - val_loss: 2.2471
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3985 - val_loss: 2.0612
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3965 - val_loss: 2.1981
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1681 - val_loss: 2.1041
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2719 - val_loss: 2.1847
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1612 - val_loss: 2.0019
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3995 - val_loss: 2.1393
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1955 - val_loss: 2.0823
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0981 - val_loss: 2.0686
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1014 - val_loss: 1.9836
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2322 - val_loss: 2.0447
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0447 - val_loss: 1.9178
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1001 - val_loss: 1.9279
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.0653 - val_loss: 1.9225
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9809 - val_loss: 1.8727
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1623 - val_loss: 1.9118
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8688 - val_loss: 1.8713
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9333 - val_loss: 1.8379
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9362 - val_loss: 2.0049
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9837 - val_loss: 1.8615
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2342 - val_loss: 1.8223
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0533 - val_loss: 2.0321
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1073 - val_loss: 1.8771
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0851 - val_loss: 2.0789
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0268 - val_loss: 1.7878
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9284 - val_loss: 1.7677
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8380 - val_loss: 1.7534
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7894 - val_loss: 1.7520
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0327 - val_loss: 2.1750
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0679 - val_loss: 1.8495
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.9998 - val_loss: 1.8357
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0840 - val_loss: 1.7901
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1405 - val_loss: 1.7297
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7175 - val_loss: 1.7125
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8689 - val_loss: 1.7291
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8330 - val_loss: 1.6946
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8461 - val_loss: 1.8865
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7537 - val_loss: 1.8579
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9786 - val_loss: 2.0543
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8293 - val_loss: 1.7138
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6974 - val_loss: 1.8090
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7425 - val_loss: 1.6530
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6683 - val_loss: 1.7551
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5886 - val_loss: 1.6716
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6492 - val_loss: 1.8280
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4717 - val_loss: 1.7314
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6666 - val_loss: 1.7573
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8005 - val_loss: 1.6960
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6168 - val_loss: 1.7456
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5504 - val_loss: 1.7185
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6652 - val_loss: 1.9190
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7341 - val_loss: 1.8009
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6672 - val_loss: 1.7129
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6455 - val_loss: 1.7497
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7279 - val_loss: 1.8402
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8743 - val_loss: 1.7844
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5876 - val_loss: 1.7272
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6775 - val_loss: 1.7348
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4375 - val_loss: 1.7662
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5547 - val_loss: 1.8181
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5256 - val_loss: 1.7600
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7283 - val_loss: 1.8009
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5804 - val_loss: 1.8250
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5947 - val_loss: 1.7475
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7736 - val_loss: 1.8979
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7076 - val_loss: 1.7792
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5459 - val_loss: 1.7513
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5457 - val_loss: 1.7538
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3979 - val_loss: 1.7328
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4583 - val_loss: 1.7882
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5401 - val_loss: 1.7475
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5641 - val_loss: 1.6886
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5223 - val_loss: 1.7734
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3993 - val_loss: 1.7112
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5395 - val_loss: 1.7743
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4712 - val_loss: 1.7641
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4115 - val_loss: 1.8194
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5202 - val_loss: 1.7132
# CPU times: total: 1min 53s
# Wall time: 1min 41s

# %%
plt.plot(history_original.history['loss'], label='loss')
plt.plot(history_original.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()


# Comparar Original vs Variación 1
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion1.history['loss'], label='Variación 1 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion1.history['val_loss'], '--', label='Variación 1 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 1')
plt.legend()
plt.show()

# Comparar Original vs Variación 2
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion2.history['loss'], label='Variación 2 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion2.history['val_loss'], '--', label='Variación 2 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 2')
plt.legend()
plt.show()

# Comparar Original vs Variación 3
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion3.history['loss'], label='Variación 3 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion3.history['val_loss'], '--', label='Variación 3 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 3')
plt.legend()
plt.show()

# %%
test_res['dnn_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# variacion 1
test_res['variacion1_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)


# variacion 2
test_res['variacion2_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# variacion 3
test_res['variacion3_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'linear_model': 2.7763447761535645,
#  'dnn_model': 2.312346935272217,
#  'variacion1_model': 2.312346935272217,
#  'variacion2_model': 2.312346935272217,
#  'variacion3_model': 2.312346935272217}

# %%
test_pred = dnn_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()

# variacion 1
test_pred = variacion1_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()

# variacion 2
test_pred = variacion2_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()

# variacion 3
test_pred = variacion3_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023C843CD620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023C843CD620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

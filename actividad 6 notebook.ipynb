# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 11-12: Introducción a redes neuronales
#
# - Redes densas
# - Redes para regresión
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy y pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('auto-mpg.data',
                 names=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin'],
                 sep=' ',
                 na_values='?',
                 comment='\t',
                 skipinitialspace=True
                 )

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df=df.drop(["Origin"], axis=1)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %% [markdown]
# - MPG: miles per gallon
# - Cylinders: # de cilindros
# - Displacement: volumen desplazado por los pistones
# - Horsepower: caballos de potencia
# - Weight: peso
# - Acceleration: aceleración
# - Model Year: año/modelo
# - Origin: 1:USA, 2:Europa, 3:Japón

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (398, 7)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %% [markdown]
# Separamos los datos en entrenamiento y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 125  20.0          6         198.0        95.0  3102.0          16.5
# 142  26.0          4          79.0        67.0  1963.0          15.5
# 278  31.5          4          89.0        71.0  1990.0          14.9
# 254  20.2          6         200.0        85.0  2965.0          15.8
# 328  30.0          4         146.0        67.0  3250.0          21.8
#
#      Model Year
# 125          74
# 142          74
# 278          78
# 254          78
# 328          80

# %%
test = df.drop(train.index)
test.head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0   18.0          8         307.0       130.0  3504.0          12.0
# 2   18.0          8         318.0       150.0  3436.0          11.0
# 4   17.0          8         302.0       140.0  3449.0          10.5
# 8   14.0          8         455.0       225.0  4425.0          10.0
# 13  14.0          8         455.0       225.0  3086.0          10.0
#
#     Model Year
# 0           70
# 2           70
# 4           70
# 8           70
# 13          70

# %%
print(train.shape)
print(test.shape)
# Out:
# (314, 7)
# (78, 7)

# %% [markdown]
# Realicemos una exploración descriptiva de los datos, calculando inicialmente estadísticas de cada variable continua

# %%
train.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.579299    5.455414    192.562102  103.767516  2959.312102
# std      7.877216    1.691811    103.701434   38.123560   856.880939
# min      9.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.125000    4.000000     98.000000   75.000000  2193.000000
# 50%     23.000000    4.000000    146.000000   94.500000  2764.500000
# 75%     29.375000    8.000000    260.000000  120.000000  3612.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year
# count    314.000000  314.000000
# mean      15.518471   75.964968
# std        2.705097    3.672110
# min        8.000000   70.000000
# 25%       13.900000   73.000000
# 50%       15.500000   76.000000
# 75%       17.000000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Exploremos relaciones bivariadas con pairplot de seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(train)

# %% [markdown]
# Calculemos la matriz de correlacion

# %%
train.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777230     -0.807032   -0.775493 -0.832793
# Cylinders    -0.777230   1.000000      0.950858    0.849237  0.901259
# Displacement -0.807032   0.950858      1.000000    0.893640  0.941913
# Horsepower   -0.775493   0.849237      0.893640    1.000000  0.875157
# Weight       -0.832793   0.901259      0.941913    0.875157  1.000000
# Acceleration  0.389422  -0.488703     -0.523473   -0.672989 -0.402870
# Model Year    0.596816  -0.330668     -0.364236   -0.414065 -0.318231
#
#               Acceleration  Model Year
# MPG               0.389422    0.596816
# Cylinders        -0.488703   -0.330668
# Displacement     -0.523473   -0.364236
# Horsepower       -0.672989   -0.414065
# Weight           -0.402870   -0.318231
# Acceleration      1.000000    0.258013
# Model Year        0.258013    1.000000

# %%
sns.heatmap(train.corr())
# Out:
# <Axes: >

# %% [markdown]
# Seleccionamos ahora las características y las etiquetas (MPG)

# %%
train_X = train.copy()
test_X = test.copy()

# %%
train_y = train_X.pop('MPG')
test_y = test_X.pop('MPG')

# %%
train_X.head()
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74
# 142          4          79.0        67.0  1963.0          15.5          74
# 278          4          89.0        71.0  1990.0          14.9          78
# 254          6         200.0        85.0  2965.0          15.8          78
# 328          4         146.0        67.0  3250.0          21.8          80

# %%
train_y.head()
# Out:
# 125    20.0
# 142    26.0
# 278    31.5
# 254    20.2
# 328    30.0
# Name: MPG, dtype: float64

# %%
train_X.dtypes
# Out:
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model Year        int64
# dtype: object

# %% [markdown]
# Construyamos los modelos usando tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Capa de normalización

# %%
tf.keras.layers.Normalization
# Out:
# keras.src.layers.preprocessing.normalization.Normalization

# %%
norm = tf.keras.layers.Normalization()

# %%
norm.adapt(np.array(train_X))

# %%
norm.mean.numpy()
# Out:
# array([[   5.455414,  192.5621  ,  103.76752 , 2959.312   ,   15.518472,
#           75.964966]], dtype=float32)

# %%
norm.variance.numpy()
# Out:
# array([[2.8531077e+00, 1.0719739e+04, 1.4487772e+03, 7.3190656e+05,
#         7.2942448e+00, 1.3441448e+01]], dtype=float32)

# %%
np.sqrt(norm.variance.numpy())
# Out:
# array([[  1.6891145, 103.53617  ,  38.062805 , 855.5154   ,   2.7007859,
#           3.666258 ]], dtype=float32)

# %%
train_X[:1]
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74

# %%
norm(train_X[:1]).numpy()
# Out:
# array([[ 0.32240927,  0.05252171, -0.23034343,  0.166786  ,  0.36342323,
#         -0.5359595 ]], dtype=float32)

# %% [markdown]
# ## Modelos con una variable de entrada

# %%
hpower = np.array(train_X['Horsepower'])

# %%
hpower_norm = tf.keras.layers.Normalization(input_shape=[1,], axis=None)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
hpower_norm.adapt(hpower)

# %%
h_model = tf.keras.Sequential([
    hpower_norm,
    tf.keras.layers.Dense(units=1)
])

# %%
h_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5 (24.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 3 (16.00 B)

# %%
h_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = h_model.fit(
    train_X['Horsepower'],
    train_y,
    epochs=100,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 23.0448 - val_loss: 21.8247
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.8680 - val_loss: 21.0536
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.3930 - val_loss: 20.2886
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.1437 - val_loss: 19.5030
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.4146 - val_loss: 18.7145
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.4269 - val_loss: 17.9383
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.3542 - val_loss: 17.1467
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9152 - val_loss: 16.3700
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6827 - val_loss: 15.5943
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.6972 - val_loss: 14.8168
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.2228 - val_loss: 14.0338
# Epoch 12/100
# ...

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# %%
hist.head()
# Out:
#         loss   val_loss  epoch
# 0  23.493881  21.824677      0
# 1  22.672525  21.053612      1
# 2  21.878845  20.288582      2
# 3  21.060047  19.503046      3
# 4  20.256197  18.714453      4

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res = {}
test_res['h_model'] = h_model.evaluate(
    test_X['Horsepower'],
    test_y, verbose=0)

# %%
test_res
# Out:
# {'h_model': 3.679682731628418}

# %%
df['Horsepower'].describe()
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: Horsepower, dtype: float64

# %%
x = tf.linspace(0.0, 250, 251) #start, stop, num
y = h_model.predict(x)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
plt.scatter(train_X['Horsepower'], train_y, label='Data')
plt.plot(x, y, color='k', label='Predictions')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.legend()

# %%
dnn_h_model = tf.keras.Sequential([
      hpower_norm,
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# variacion 1
variacion1_model = tf.keras.Sequential([
      hpower_norm,
      tf.keras.layers.Dense(24, activation='relu'),
      tf.keras.layers.Dense(24, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 2
variacion2_model = tf.keras.Sequential([
      hpower_norm,
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 3
variacion3_model = tf.keras.Sequential([
      hpower_norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# %%
dnn_h_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 1
variacion1_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 2
variacion2_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 3
variacion3_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
dnn_h_model.summary()

# variacion 1
variacion1_model.summary()


# variacion 2
variacion2_model.summary()


# variacion 3
variacion3_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 324 (1.27 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 3 (16.00 B)
# ...

# %%
# %%time
history_original = dnn_h_model.fit(
    train_X['Horsepower'],
    train_y,
    validation_split=0.2,
    epochs=100)

# variacion 1
history_variacion1 = variacion1_model.fit(
    train_X['Horsepower'],
    train_y,
    validation_split=0.2,
    epochs=100)


# variacion 2
history_variacion2 = variacion2_model.fit(
    train_X['Horsepower'],
    train_y,
    validation_split=0.2,
    epochs=100)

# variacion 3
history_variacion3 = variacion3_model.fit(
    train_X['Horsepower'],
    train_y,
    validation_split=0.2,
    epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5486 - val_loss: 2.9973
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4902 - val_loss: 2.9852
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5055 - val_loss: 2.9927
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2745 - val_loss: 3.0123
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6476 - val_loss: 3.0027
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3485 - val_loss: 3.0204
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3680 - val_loss: 3.0095
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2953 - val_loss: 2.9878
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3909 - val_loss: 3.0155
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2538 - val_loss: 3.0346
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5018 - val_loss: 3.0166
# Epoch 12/100
# ...

# %%
# Comparar Original vs Variación 1
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion1.history['loss'], label='Variación 1 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion1.history['val_loss'], '--', label='Variación 1 Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 1')
plt.legend()
plt.show()

# Comparar Original vs Variación 2
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion2.history['loss'], label='Variación 2 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion2.history['val_loss'], '--', label='Variación 2 Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 2')
plt.legend()
plt.show()

# Comparar Original vs Variación 3
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion3.history['loss'], label='Variación 3 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion3.history['val_loss'], '--', label='Variación 3 Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 3')
plt.legend()
plt.show()

# %%
x_original = tf.linspace(0.0, 250, 251)
y_original = dnn_h_model.predict(x)

# variacion 1
x_1= tf.linspace(0.0, 250, 251)
y_1 = variacion1_model.predict(x)


# variacion 2
x_2= tf.linspace(0.0, 250, 251)
y_2 = variacion2_model.predict(x)

# variacion 3
x_3= tf.linspace(0.0, 250, 251)
y_3 = variacion3_model.predict(x)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000025A49B57920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ...

# %%
plt.scatter(train_X['Horsepower'], train_y, label='Data')
plt.plot(x_original, y_original, color='k', label='Predictions')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Original')
plt.legend()
plt.show()

# variacion 1
plt.scatter(train_X['Horsepower'], train_y, label='Data')
plt.plot(x_1, y_1, color='k', label='Predictions')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Variación 1')
plt.legend()
plt.show()

# variacion 2
plt.scatter(train_X['Horsepower'], train_y, label='Data')
plt.plot(x_2, y_2, color='k', label='Predictions')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Variación 2')
plt.legend()
plt.show()

# variacion 3
plt.scatter(train_X['Horsepower'], train_y, label='Data')
plt.plot(x_3, y_3, color='k', label='Predictions')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Variación 3')
plt.legend()
plt.show()

# %%
test_res['dnn_h_model'] = dnn_h_model.evaluate(
    test_X['Horsepower'], test_y,
    verbose=0)

# variacion 1
test_res['variacion1_model'] = variacion1_model.evaluate(
    test_X['Horsepower'], test_y,
    verbose=0)

# variacion 2
test_res['variacion2_model'] = variacion2_model.evaluate(
    test_X['Horsepower'], test_y,
    verbose=0)

# variacion 3
test_res['variacion3_model'] = variacion3_model.evaluate(
    test_X['Horsepower'], test_y,
    verbose=0)

# %%
test_res
# Out:
# {'h_model': 3.679682731628418,
#  'dnn_h_model': 2.896932363510132,
#  'variacion1_model': 2.8959577083587646,
#  'variacion2_model': 2.8939404487609863,
#  'variacion3_model': 2.888131618499756}

# %% [markdown]
# ## Modelo con múltiples variables de entrada

# %%
linear_model = tf.keras.Sequential([
    norm,
    tf.keras.layers.Dense(units=1)
])

# %%
linear_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (314, 6)               │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_X,
    train_y,
    epochs=100,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 23.3681 - val_loss: 21.8603
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.1116 - val_loss: 21.1923
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.9615 - val_loss: 20.4707
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.2772 - val_loss: 19.8053
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3047 - val_loss: 19.1121
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.5442 - val_loss: 18.4114
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.6714 - val_loss: 17.7063
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.0545 - val_loss: 17.0277
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.0608 - val_loss: 16.3539
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.2516 - val_loss: 15.6551
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.3905 - val_loss: 14.9802
# Epoch 12/100
# ...

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res['linear_model'] = linear_model.evaluate(
    test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'h_model': 3.6827995777130127,
#  'dnn_h_model': 3.232196569442749,
#  'linear_model': 2.784219741821289}

# %%
dnn_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# %%
dnn_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
dnn_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
# %%time
history = dnn_model.fit(
  train_X,
  train_y,
  validation_split=0.2,
  epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 23.2802 - val_loss: 21.9164
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.3270 - val_loss: 21.3209
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.2355 - val_loss: 20.5881
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.8505 - val_loss: 19.6518
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.7601 - val_loss: 18.4164
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.9162 - val_loss: 16.7923
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.3642 - val_loss: 14.9655
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.0072 - val_loss: 13.0104
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.7694 - val_loss: 11.0265
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1631 - val_loss: 8.6693
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1377 - val_loss: 5.9070
# Epoch 12/100
# ...

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res['dnn_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'h_model': 3.6827995777130127,
#  'dnn_h_model': 3.232196569442749,
#  'linear_model': 2.784219741821289,
#  'dnn_model': 2.275967836380005}

# %%
test_pred = dnn_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_=plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A4B77D9D00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 11-12: Introducción a redes neuronales
#
# - Redes densas
# - Redes para regresión
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy y pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('auto-mpg.data',
                 names=['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin'],
                 sep=' ',
                 na_values='?',
                 comment='\t',
                 skipinitialspace=True
                 )

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df=df.drop(["Origin"], axis=1)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 7 columns]

# %% [markdown]
# - MPG: miles per gallon
# - Cylinders: # de cilindros
# - Displacement: volumen desplazado por los pistones
# - Horsepower: caballos de potencia
# - Weight: peso
# - Acceleration: aceleración
# - Model Year: año/modelo
# - Origin: 1:USA, 2:Europa, 3:Japón

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (398, 7)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %% [markdown]
# Separamos los datos en entrenamiento y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 125  20.0          6         198.0        95.0  3102.0          16.5
# 142  26.0          4          79.0        67.0  1963.0          15.5
# 278  31.5          4          89.0        71.0  1990.0          14.9
# 254  20.2          6         200.0        85.0  2965.0          15.8
# 328  30.0          4         146.0        67.0  3250.0          21.8
#
#      Model Year
# 125          74
# 142          74
# 278          78
# 254          78
# 328          80

# %%
test = df.drop(train.index)
test.head()
# Out:
#      MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0   18.0          8         307.0       130.0  3504.0          12.0
# 2   18.0          8         318.0       150.0  3436.0          11.0
# 4   17.0          8         302.0       140.0  3449.0          10.5
# 8   14.0          8         455.0       225.0  4425.0          10.0
# 13  14.0          8         455.0       225.0  3086.0          10.0
#
#     Model Year
# 0           70
# 2           70
# 4           70
# 8           70
# 13          70

# %%
print(train.shape)
print(test.shape)
# Out:
# (314, 7)
# (78, 7)

# %% [markdown]
# Realicemos una exploración descriptiva de los datos, calculando inicialmente estadísticas de cada variable continua

# %%
train.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.579299    5.455414    192.562102  103.767516  2959.312102
# std      7.877216    1.691811    103.701434   38.123560   856.880939
# min      9.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.125000    4.000000     98.000000   75.000000  2193.000000
# 50%     23.000000    4.000000    146.000000   94.500000  2764.500000
# 75%     29.375000    8.000000    260.000000  120.000000  3612.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year
# count    314.000000  314.000000
# mean      15.518471   75.964968
# std        2.705097    3.672110
# min        8.000000   70.000000
# 25%       13.900000   73.000000
# 50%       15.500000   76.000000
# 75%       17.000000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Exploremos relaciones bivariadas con pairplot de seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(train)

# %% [markdown]
# Calculemos la matriz de correlacion

# %%
train.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777230     -0.807032   -0.775493 -0.832793
# Cylinders    -0.777230   1.000000      0.950858    0.849237  0.901259
# Displacement -0.807032   0.950858      1.000000    0.893640  0.941913
# Horsepower   -0.775493   0.849237      0.893640    1.000000  0.875157
# Weight       -0.832793   0.901259      0.941913    0.875157  1.000000
# Acceleration  0.389422  -0.488703     -0.523473   -0.672989 -0.402870
# Model Year    0.596816  -0.330668     -0.364236   -0.414065 -0.318231
#
#               Acceleration  Model Year
# MPG               0.389422    0.596816
# Cylinders        -0.488703   -0.330668
# Displacement     -0.523473   -0.364236
# Horsepower       -0.672989   -0.414065
# Weight           -0.402870   -0.318231
# Acceleration      1.000000    0.258013
# Model Year        0.258013    1.000000

# %%
sns.heatmap(train.corr())
# Out:
# <Axes: >

# %% [markdown]
# Seleccionamos ahora las características y las etiquetas (MPG)

# %%
train_X = train.copy()
test_X = test.copy()

# %%
train_y = train_X.pop('MPG')
test_y = test_X.pop('MPG')

# %%
train_X.head()
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74
# 142          4          79.0        67.0  1963.0          15.5          74
# 278          4          89.0        71.0  1990.0          14.9          78
# 254          6         200.0        85.0  2965.0          15.8          78
# 328          4         146.0        67.0  3250.0          21.8          80

# %%
train_y.head()
# Out:
# 125    20.0
# 142    26.0
# 278    31.5
# 254    20.2
# 328    30.0
# Name: MPG, dtype: float64

# %%
train_X.dtypes
# Out:
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model Year        int64
# dtype: object

# %% [markdown]
# Construyamos los modelos usando tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Capa de normalización

# %%
tf.keras.layers.Normalization
# Out:
# keras.src.layers.preprocessing.normalization.Normalization

# %%
norm = tf.keras.layers.Normalization()

# %%
norm.adapt(np.array(train_X))

# %%
norm.mean.numpy()
# Out:
# array([[   5.455414,  192.5621  ,  103.76752 , 2959.312   ,   15.518472,
#           75.964966]], dtype=float32)

# %%
norm.variance.numpy()
# Out:
# array([[2.8531077e+00, 1.0719739e+04, 1.4487772e+03, 7.3190656e+05,
#         7.2942448e+00, 1.3441448e+01]], dtype=float32)

# %%
np.sqrt(norm.variance.numpy())
# Out:
# array([[  1.6891145, 103.53617  ,  38.062805 , 855.5154   ,   2.7007859,
#           3.666258 ]], dtype=float32)

# %%
train_X[:1]
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 125          6         198.0        95.0  3102.0          16.5          74

# %%
norm(train_X[:1]).numpy()
# Out:
# array([[ 0.32240927,  0.05252171, -0.23034343,  0.166786  ,  0.36342323,
#         -0.5359595 ]], dtype=float32)

# %% [markdown]
# ## Modelo con múltiples variables de entrada

# %%
linear_model = tf.keras.Sequential([
    norm,
    tf.keras.layers.Dense(units=1)
])

# %%
linear_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (314, 6)               │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %%time
history = linear_model.fit(
    train_X,
    train_y,
    epochs=100,
    validation_split = 0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.2570 - val_loss: 21.6513
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.2290 - val_loss: 21.0055
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.1877 - val_loss: 20.4143
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.2317 - val_loss: 19.7116
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.3087 - val_loss: 19.0597
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.7260 - val_loss: 18.4160
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.2599 - val_loss: 17.6966
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9934 - val_loss: 17.0904
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.7678 - val_loss: 16.4336
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.4875 - val_loss: 15.7663
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.4012 - val_loss: 15.0472
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.5853 - val_loss: 14.3863
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.6910 - val_loss: 13.6735
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.1418 - val_loss: 13.0180
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.1072 - val_loss: 12.3993
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.2195 - val_loss: 11.7336
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.2901 - val_loss: 11.0669
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5420 - val_loss: 10.3096
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5556 - val_loss: 9.5151
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1584 - val_loss: 8.6440
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6616 - val_loss: 7.6801
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9683 - val_loss: 6.8095
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1264 - val_loss: 6.0469
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0170 - val_loss: 5.1726
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6621 - val_loss: 4.4626
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2469 - val_loss: 3.7478
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8367 - val_loss: 3.1279
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5334 - val_loss: 2.6807
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2101 - val_loss: 2.5537
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7589 - val_loss: 2.4658
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9226 - val_loss: 2.3619
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8140 - val_loss: 2.3463
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7059 - val_loss: 2.2588
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7906 - val_loss: 2.2758
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6796 - val_loss: 2.2520
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8207 - val_loss: 2.2602
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7996 - val_loss: 2.2294
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9191 - val_loss: 2.3294
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6247 - val_loss: 2.2614
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7214 - val_loss: 2.2228
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5359 - val_loss: 2.2301
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6306 - val_loss: 2.2357
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7402 - val_loss: 2.3758
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7728 - val_loss: 2.2333
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4903 - val_loss: 2.2713
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6245 - val_loss: 2.2351
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5099 - val_loss: 2.2970
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5433 - val_loss: 2.2535
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5667 - val_loss: 2.2558
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5254 - val_loss: 2.2550
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5500 - val_loss: 2.2925
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4702 - val_loss: 2.2586
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4684 - val_loss: 2.3066
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6030 - val_loss: 2.2267
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7235 - val_loss: 2.2642
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7044 - val_loss: 2.2426
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4520 - val_loss: 2.2957
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5678 - val_loss: 2.2977
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7932 - val_loss: 2.2312
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7578 - val_loss: 2.2945
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5283 - val_loss: 2.3197
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5652 - val_loss: 2.2506
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6340 - val_loss: 2.3056
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7175 - val_loss: 2.2420
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8391 - val_loss: 2.3209
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5923 - val_loss: 2.2268
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8616 - val_loss: 2.3054
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7306 - val_loss: 2.2553
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5617 - val_loss: 2.3142
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5432 - val_loss: 2.2370
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5164 - val_loss: 2.3233
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7897 - val_loss: 2.2285
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5049 - val_loss: 2.2984
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6129 - val_loss: 2.2472
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5192 - val_loss: 2.2948
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5377 - val_loss: 2.2856
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7248 - val_loss: 2.2925
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7712 - val_loss: 2.2299
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6551 - val_loss: 2.3336
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4061 - val_loss: 2.2464
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3318 - val_loss: 2.2692
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5435 - val_loss: 2.3172
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6692 - val_loss: 2.2471
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5231 - val_loss: 2.2394
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4089 - val_loss: 2.4080
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6212 - val_loss: 2.2268
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4128 - val_loss: 2.3077
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6084 - val_loss: 2.2994
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6601 - val_loss: 2.2171
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7903 - val_loss: 2.2756
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6395 - val_loss: 2.3012
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5648 - val_loss: 2.2750
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5591 - val_loss: 2.2270
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4185 - val_loss: 2.3670
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6495 - val_loss: 2.2730
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7668 - val_loss: 2.2166
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6618 - val_loss: 2.3338
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7014 - val_loss: 2.2291
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6314 - val_loss: 2.2532
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6092 - val_loss: 2.3172
# CPU times: total: 1.22 s
# Wall time: 4.8 s

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
test_res = {}
test_res['linear_model'] = linear_model.evaluate(
    test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'linear_model': 2.7650935649871826}

# %%
dnn_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# variacion 1
variacion1_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 2
variacion2_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(24, activation='relu'),
      tf.keras.layers.Dense(24, activation='relu'),
      tf.keras.layers.Dense(1)
  ])


# variacion 3
variacion3_model = tf.keras.Sequential([
      norm,
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dense(16, activation='relu'),
      tf.keras.layers.Dense(1)
  ])

# %%
dnn_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# variacion 1
variacion1_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 2
variacion2_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))


# variacion 3
variacion3_model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))

# %%
dnn_model.summary()

# variacion 1
variacion1_model.summary()


# variacion 2
variacion2_model.summary()


# variacion 3
variacion3_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 6)              │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
# %%time
history_original = dnn_model.fit(
  train_X,
  train_y,
  validation_split=0.2,
  epochs=100)

  # variacion 1
history_variacion1 = variacion1_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)


# variacion 2
history_variacion2 = variacion2_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)

# variacion 3
history_variacion3 = variacion3_model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 23.5970 - val_loss: 22.1032
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.3054 - val_loss: 21.6268
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.0899 - val_loss: 21.0416
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.2390 - val_loss: 20.2858
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.7794 - val_loss: 19.2652
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3779 - val_loss: 17.8654
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.2406 - val_loss: 16.3247
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.8148 - val_loss: 14.8843
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.7703 - val_loss: 13.4610
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.4432 - val_loss: 11.7444
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.7820 - val_loss: 9.4603
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3871 - val_loss: 6.5845
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5364 - val_loss: 4.6424
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9675 - val_loss: 4.6519
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9269 - val_loss: 4.2703
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6688 - val_loss: 3.9055
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2998 - val_loss: 3.7160
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8849 - val_loss: 3.4895
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9203 - val_loss: 3.2776
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8494 - val_loss: 3.1011
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6630 - val_loss: 2.9687
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5906 - val_loss: 2.8966
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3194 - val_loss: 2.8111
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3740 - val_loss: 2.6968
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8265 - val_loss: 2.5716
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9674 - val_loss: 2.4962
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0994 - val_loss: 2.4230
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7459 - val_loss: 2.3665
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6751 - val_loss: 2.3282
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8263 - val_loss: 2.2683
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7085 - val_loss: 2.2026
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7373 - val_loss: 2.1839
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5158 - val_loss: 2.1305
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6158 - val_loss: 2.1022
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5857 - val_loss: 2.0874
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5761 - val_loss: 2.0777
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3698 - val_loss: 2.0068
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2734 - val_loss: 2.0339
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2355 - val_loss: 2.0432
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4311 - val_loss: 1.9844
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2854 - val_loss: 1.9962
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3845 - val_loss: 1.9874
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4805 - val_loss: 1.9360
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2678 - val_loss: 1.9999
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3309 - val_loss: 1.9044
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2335 - val_loss: 1.9099
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2294 - val_loss: 1.9234
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0975 - val_loss: 1.9155
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1849 - val_loss: 1.9130
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3098 - val_loss: 1.9002
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1758 - val_loss: 1.8764
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9875 - val_loss: 1.8991
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3220 - val_loss: 1.8994
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1973 - val_loss: 1.8591
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2701 - val_loss: 1.8683
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1459 - val_loss: 1.9009
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1651 - val_loss: 1.8272
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1089 - val_loss: 1.8496
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0685 - val_loss: 1.8535
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0701 - val_loss: 1.9018
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0192 - val_loss: 1.8502
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0095 - val_loss: 1.8313
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1467 - val_loss: 1.8110
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0886 - val_loss: 1.8541
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9631 - val_loss: 1.8197
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0834 - val_loss: 1.8365
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0361 - val_loss: 1.8331
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0587 - val_loss: 1.8240
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0695 - val_loss: 1.8084
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9647 - val_loss: 1.8297
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0291 - val_loss: 1.7949
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1260 - val_loss: 1.8111
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0738 - val_loss: 1.8220
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0016 - val_loss: 1.7907
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1730 - val_loss: 1.8453
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8745 - val_loss: 1.7754
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9611 - val_loss: 1.8041
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0004 - val_loss: 1.7869
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9464 - val_loss: 1.7758
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1963 - val_loss: 1.7962
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9697 - val_loss: 1.8159
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9951 - val_loss: 1.7836
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9356 - val_loss: 1.8055
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9332 - val_loss: 1.7755
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0054 - val_loss: 1.7733
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9504 - val_loss: 1.8094
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8771 - val_loss: 1.7743
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0645 - val_loss: 1.7786
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8480 - val_loss: 1.7938
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0324 - val_loss: 1.7567
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7771 - val_loss: 1.7700
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9582 - val_loss: 1.7682
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0168 - val_loss: 1.7494
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8929 - val_loss: 1.7564
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9794 - val_loss: 1.7594
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9075 - val_loss: 1.7673
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8197 - val_loss: 1.7562
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0143 - val_loss: 1.7614
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0005 - val_loss: 1.7343
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9215 - val_loss: 1.7336
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 23.6379 - val_loss: 22.4493
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.4404 - val_loss: 22.1323
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.6148 - val_loss: 21.8126
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.3568 - val_loss: 21.4639
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.4636 - val_loss: 21.0634
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.0162 - val_loss: 20.5980
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.5254 - val_loss: 20.0325
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.3354 - val_loss: 19.3624
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3377 - val_loss: 18.5650
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.6401 - val_loss: 17.6145
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.4904 - val_loss: 16.4893
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.8620 - val_loss: 15.2958
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.3124 - val_loss: 14.0887
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.1645 - val_loss: 12.9554
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.6836 - val_loss: 11.7292
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.7575 - val_loss: 10.2992
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.0360 - val_loss: 8.6807
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6915 - val_loss: 7.0943
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1496 - val_loss: 5.8524
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4865 - val_loss: 5.5631
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8191 - val_loss: 5.5334
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9305 - val_loss: 5.3674
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4321 - val_loss: 5.1042
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6797 - val_loss: 4.8787
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3881 - val_loss: 4.7016
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0580 - val_loss: 4.5286
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7832 - val_loss: 4.3496
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0721 - val_loss: 4.1668
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2374 - val_loss: 3.9886
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1499 - val_loss: 3.8249
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0115 - val_loss: 3.6734
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9637 - val_loss: 3.5231
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6404 - val_loss: 3.3801
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1243 - val_loss: 3.2609
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7878 - val_loss: 3.1297
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2146 - val_loss: 3.0517
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5783 - val_loss: 2.9717
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1239 - val_loss: 2.8949
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2658 - val_loss: 2.8009
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5861 - val_loss: 2.7503
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0272 - val_loss: 2.6598
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0596 - val_loss: 2.5960
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0434 - val_loss: 2.5303
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9384 - val_loss: 2.4561
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0196 - val_loss: 2.4373
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8316 - val_loss: 2.3725
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8955 - val_loss: 2.3424
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6269 - val_loss: 2.3134
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6111 - val_loss: 2.2691
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5361 - val_loss: 2.2565
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4824 - val_loss: 2.2296
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6928 - val_loss: 2.1937
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5414 - val_loss: 2.1437
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3700 - val_loss: 2.1347
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5215 - val_loss: 2.1604
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5622 - val_loss: 2.0946
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2590 - val_loss: 2.0783
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3856 - val_loss: 2.0211
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3848 - val_loss: 2.0698
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2857 - val_loss: 2.0341
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2967 - val_loss: 1.9922
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1955 - val_loss: 2.0011
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2341 - val_loss: 1.9731
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1597 - val_loss: 1.9505
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2106 - val_loss: 1.9518
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1852 - val_loss: 1.9289
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2953 - val_loss: 1.9098
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0979 - val_loss: 1.9235
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1605 - val_loss: 1.8995
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2365 - val_loss: 1.8872
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1578 - val_loss: 1.8932
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0566 - val_loss: 1.8591
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1648 - val_loss: 1.8770
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2225 - val_loss: 1.8635
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1197 - val_loss: 1.8471
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2628 - val_loss: 1.8548
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1926 - val_loss: 1.8387
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1405 - val_loss: 1.8380
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0262 - val_loss: 1.8010
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1056 - val_loss: 1.8478
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1825 - val_loss: 1.8336
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0434 - val_loss: 1.8182
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9198 - val_loss: 1.8696
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0455 - val_loss: 1.8166
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2576 - val_loss: 1.8230
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2722 - val_loss: 1.8222
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0506 - val_loss: 1.8460
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1129 - val_loss: 1.7880
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0759 - val_loss: 1.8172
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1649 - val_loss: 1.8521
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0793 - val_loss: 1.8090
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9040 - val_loss: 1.8118
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0347 - val_loss: 1.8168
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0417 - val_loss: 1.8058
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9826 - val_loss: 1.8070
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1337 - val_loss: 1.8179
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9492 - val_loss: 1.7759
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9121 - val_loss: 1.8081
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0415 - val_loss: 1.7924
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0668 - val_loss: 1.8059
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 23.5454 - val_loss: 22.4244
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.3073 - val_loss: 22.2245
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.4757 - val_loss: 22.0183
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0034 - val_loss: 21.7993
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.6495 - val_loss: 21.5579
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.9923 - val_loss: 21.2658
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.4861 - val_loss: 20.8998
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.5000 - val_loss: 20.4238
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.8104 - val_loss: 19.8143
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.5840 - val_loss: 19.0595
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.3691 - val_loss: 18.1369
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.4176 - val_loss: 17.1540
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.7510 - val_loss: 16.1546
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.6330 - val_loss: 15.2168
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.2669 - val_loss: 14.3835
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.1606 - val_loss: 13.5439
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.0769 - val_loss: 12.5944
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.3964 - val_loss: 11.4904
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.2026 - val_loss: 10.1976
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.8700 - val_loss: 8.7271
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4470 - val_loss: 7.0533
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3701 - val_loss: 5.4351
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7115 - val_loss: 4.5531
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2474 - val_loss: 4.4213
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3994 - val_loss: 4.2781
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8577 - val_loss: 4.1097
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9670 - val_loss: 3.9580
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6389 - val_loss: 3.8200
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3122 - val_loss: 3.6841
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5140 - val_loss: 3.5481
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2597 - val_loss: 3.4571
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2369 - val_loss: 3.3381
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0381 - val_loss: 3.2602
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9406 - val_loss: 3.1560
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8375 - val_loss: 3.0594
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6430 - val_loss: 2.9686
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6164 - val_loss: 2.8830
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3872 - val_loss: 2.7881
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1843 - val_loss: 2.6886
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2399 - val_loss: 2.5815
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2096 - val_loss: 2.4932
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1258 - val_loss: 2.4176
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8844 - val_loss: 2.3618
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9290 - val_loss: 2.3028
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8913 - val_loss: 2.2573
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7328 - val_loss: 2.2232
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9117 - val_loss: 2.1884
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6686 - val_loss: 2.1338
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5472 - val_loss: 2.1194
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4904 - val_loss: 2.0734
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4991 - val_loss: 2.0273
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5771 - val_loss: 2.0172
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6661 - val_loss: 1.9830
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5331 - val_loss: 1.9714
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4444 - val_loss: 1.9605
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5116 - val_loss: 1.9173
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4371 - val_loss: 1.9025
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2014 - val_loss: 1.8752
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3708 - val_loss: 1.8611
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6151 - val_loss: 1.8835
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3927 - val_loss: 1.9148
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2440 - val_loss: 1.8701
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4508 - val_loss: 1.8512
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3563 - val_loss: 1.8866
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3036 - val_loss: 1.8406
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4162 - val_loss: 1.8477
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4663 - val_loss: 1.8779
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2569 - val_loss: 1.8125
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1667 - val_loss: 1.8062
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0876 - val_loss: 1.8488
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2925 - val_loss: 1.8904
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3719 - val_loss: 1.7758
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1505 - val_loss: 1.8611
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2030 - val_loss: 1.8052
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2172 - val_loss: 1.8066
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3580 - val_loss: 1.8366
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1309 - val_loss: 1.8219
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1280 - val_loss: 1.8292
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1597 - val_loss: 1.8348
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0362 - val_loss: 1.8275
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2824 - val_loss: 1.7928
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4540 - val_loss: 1.8698
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0847 - val_loss: 1.7547
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0227 - val_loss: 1.8163
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1313 - val_loss: 1.8422
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2066 - val_loss: 1.8167
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0591 - val_loss: 1.7871
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1171 - val_loss: 1.8246
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0819 - val_loss: 1.8006
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0931 - val_loss: 1.8275
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2537 - val_loss: 1.7666
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1145 - val_loss: 1.7516
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9548 - val_loss: 1.7548
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0185 - val_loss: 1.7819
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9779 - val_loss: 1.7432
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1562 - val_loss: 1.7259
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9831 - val_loss: 1.7826
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9827 - val_loss: 1.7842
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0300 - val_loss: 1.7394
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9831 - val_loss: 1.7637
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 24.0289 - val_loss: 22.3827
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.6030 - val_loss: 22.1810
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0757 - val_loss: 21.9704
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.4723 - val_loss: 21.7325
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.3338 - val_loss: 21.4650
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.9043 - val_loss: 21.1655
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.3644 - val_loss: 20.8353
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.6328 - val_loss: 20.4676
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.6697 - val_loss: 20.0557
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.3172 - val_loss: 19.5876
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.1506 - val_loss: 19.0181
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.9222 - val_loss: 18.3538
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.8831 - val_loss: 17.7838
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.2126 - val_loss: 17.2307
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.9254 - val_loss: 16.6883
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2148 - val_loss: 16.2173
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.8034 - val_loss: 15.7775
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.7980 - val_loss: 15.3068
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.3677 - val_loss: 14.8459
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.7306 - val_loss: 14.3493
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.8955 - val_loss: 13.7564
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.1921 - val_loss: 13.0854
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.1082 - val_loss: 12.3128
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.8765 - val_loss: 11.4554
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.1980 - val_loss: 10.5063
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.3300 - val_loss: 9.4728
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6024 - val_loss: 8.3337
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4400 - val_loss: 7.1086
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5927 - val_loss: 5.9053
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4227 - val_loss: 4.9539
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5276 - val_loss: 4.2188
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9946 - val_loss: 3.9154
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0363 - val_loss: 3.8521
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8587 - val_loss: 3.7636
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5615 - val_loss: 3.6597
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1900 - val_loss: 3.5598
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2598 - val_loss: 3.4587
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1833 - val_loss: 3.3804
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8598 - val_loss: 3.2965
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6919 - val_loss: 3.2154
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7197 - val_loss: 3.1455
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9495 - val_loss: 3.0762
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7134 - val_loss: 3.0172
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5921 - val_loss: 2.9594
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3021 - val_loss: 2.9162
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3994 - val_loss: 2.8735
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1939 - val_loss: 2.8046
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2956 - val_loss: 2.7370
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1260 - val_loss: 2.7035
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1732 - val_loss: 2.6321
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3521 - val_loss: 2.5624
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9302 - val_loss: 2.5121
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8336 - val_loss: 2.4664
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0751 - val_loss: 2.4111
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8085 - val_loss: 2.4010
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8819 - val_loss: 2.3731
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6466 - val_loss: 2.2701
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8536 - val_loss: 2.2300
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6398 - val_loss: 2.1935
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6905 - val_loss: 2.1869
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6963 - val_loss: 2.1219
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8045 - val_loss: 2.0835
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6680 - val_loss: 2.0496
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1858 - val_loss: 2.0272
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7347 - val_loss: 1.9905
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5326 - val_loss: 1.9413
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5520 - val_loss: 1.9219
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4907 - val_loss: 1.9004
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5514 - val_loss: 1.8715
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4845 - val_loss: 1.8315
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4884 - val_loss: 1.8125
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3831 - val_loss: 1.8276
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4798 - val_loss: 1.8161
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3459 - val_loss: 1.7764
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1103 - val_loss: 1.7654
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2722 - val_loss: 1.7793
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1948 - val_loss: 1.7451
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5201 - val_loss: 1.7471
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1993 - val_loss: 1.7444
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1364 - val_loss: 1.7445
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4852 - val_loss: 1.7518
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2449 - val_loss: 1.7379
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3676 - val_loss: 1.7301
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1063 - val_loss: 1.7404
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1554 - val_loss: 1.7351
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2468 - val_loss: 1.7160
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1919 - val_loss: 1.7077
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3393 - val_loss: 1.7522
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1865 - val_loss: 1.6932
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1765 - val_loss: 1.7438
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3554 - val_loss: 1.6824
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9977 - val_loss: 1.7053
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0484 - val_loss: 1.6750
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1113 - val_loss: 1.7120
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1930 - val_loss: 1.7079
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2110 - val_loss: 1.6666
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2441 - val_loss: 1.7004
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2092 - val_loss: 1.6618
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0659 - val_loss: 1.7218
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2615 - val_loss: 1.7282
# CPU times: total: 5.78 s
# Wall time: 20.1 s

# %%
plt.plot(history_original.history['loss'], label='loss')
plt.plot(history_original.history['val_loss'], label='val_loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()


# Comparar Original vs Variación 1
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion1.history['loss'], label='Variación 1 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion1.history['val_loss'], '--', label='Variación 1 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 1')
plt.legend()
plt.show()

# Comparar Original vs Variación 2
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion2.history['loss'], label='Variación 2 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion2.history['val_loss'], '--', label='Variación 2 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 2')
plt.legend()
plt.show()

# Comparar Original vs Variación 3
plt.figure(figsize=(10, 5))
plt.plot(history_original.history['loss'], label='Original Loss')
plt.plot(history_variacion3.history['loss'], label='Variación 3 Loss')
plt.plot(history_original.history['val_loss'], '--', label='Original Val Loss')
plt.plot(history_variacion3.history['val_loss'], '--', label='Variación 3 Val Loss')
plt.ylim([0, 10])
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.title('Original vs Variación 3')
plt.legend()
plt.show()

# %%
test_res['dnn_model'] = dnn_model.evaluate(test_X, test_y, verbose=0)

# variacion 1
test_res['variacion1_model'] = variacion1_model.evaluate(test_X, test_y, verbose=0)


# variacion 2
test_res['variacion2_model'] = variacion2_model.evaluate(test_X, test_y, verbose=0)

# variacion 3
test_res['variacion3_model'] = variacion3_model.evaluate(test_X, test_y, verbose=0)

# %%
test_res
# Out:
# {'linear_model': 2.7650935649871826,
#  'dnn_model': 2.2751214504241943,
#  'variacion1_model': 2.322943687438965,
#  'variacion2_model': 2.2631072998046875,
#  'variacion3_model': 2.2935023307800293}

# %%
test_pred = dnn_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("Original")
plt.show()

# variacion 1
test_pred = variacion1_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("variacion 1")
plt.show()

# variacion 2
test_pred = variacion2_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("variacion 2")
plt.show()

# variacion 3
test_pred = variacion3_model.predict(test_X).flatten()

plt.axes(aspect='equal')
plt.scatter(test_y, test_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title("variacion 3")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001CC53FB9BC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001CC53FB9BC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
